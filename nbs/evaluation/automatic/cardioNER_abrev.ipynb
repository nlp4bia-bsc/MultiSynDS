# %%
def assemble_ner_output_flat(ner_outputs):
    entities = []
    current_entity = None
    # Create a copy of the ner_outputs to avoid modifying the original
    ner_outputs = ner_outputs.copy()

    for token in ner_outputs:
        if token["label"] == "O":
            continue
        label = token["label"].replace("B-", "").replace("I-", "")
        word = token["word"].replace("Ġ", "")
        score = token["score"]

        if current_entity is None:
            # Start a new entity
            current_entity = {
                "label": label,
                "text": word.strip(),
                "start": token["start"],
                "end": token["end"],
                "score": [score],
            }
        elif current_entity["label"] == label and token["start"] == current_entity["end"]:
            # Continue current entity (must be same label and consecutive)
            current_entity["text"] += word
            current_entity["end"] = token["end"]
            current_entity["score"].append(score)
        elif current_entity["label"] == label and token["start"] == (current_entity["end"] + 1):
            # Continue current entity (must be same label and consecutive)
            current_entity["text"] += " " + word
            current_entity["end"] = token["end"]
            current_entity["score"].append(score)
        else:
            # Save current and start new
            entities.append(current_entity)
            current_entity = {
                "label": label,
                "text": word.strip(),
                "start": token["start"],
                "end": token["end"],
                "score": [score],
            }

    if current_entity:
        entities.append(current_entity)

    # Average the scores
    for ent in entities:
        ent["score"] = sum(ent["score"]) / len(ent["score"])

    return entities

def process_ner_results(ner_results):
    tag2label = {
        "O": 0,
        "B-DISEASE": 1,
        "I-DISEASE": 2,
        "B-MEDICATION": 3,
        "I-MEDICATION": 4,
        "B-PROCEDURE": 5,
        "I-PROCEDURE": 6,
        "B-SYMPTOM": 7,
        "I-SYMPTOM": 8,
    }

    label2tag = {v: k for k, v in tag2label.items()}

    proc_results = []
    for result in ner_results:
        if result['entity'] != 'O':
            proc_results.append({
                'start': result['start'],
                'end': result['end'],
                'label': label2tag[int(result['entity'].split('_')[-1])],
                'score': result['score'],
                'word': result['word'],
            })
            
    return proc_results

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

tokenizer = AutoTokenizer.from_pretrained("/gpfs/projects/bsc14/code/CardioNER/output/en/cpt_biomed_roberta_token/E120BS32LR1e4/hf")
model = AutoModelForTokenClassification.from_pretrained("/gpfs/projects/bsc14/code/CardioNER/output/en/cpt_biomed_roberta_token/E120BS32LR1e4/hf")

pipe = pipeline(
    "ner",
    model=model,
    tokenizer=tokenizer,
    device=1,  # Use GPU if available
)
# Out:
# Device set to use cuda:1

# %%
example1 = """
A 74-year-old man underwent primary percutaneous coronary intervention (pPCI) for a completely occluded proximal left anterior descending artery. During the procedure, microvascular flow distal to the block could not be established (no-reflow phenomenon) and was managed with diltiazem and nicorandil. A follow-up echocardiogram performed on the next day revealed an intraparietal echolucent apicolateral neocavitation corresponding to an intramyocardial haematoma (IMH) along with a reduced ejection fraction (EF) of 30\% compared with 45\% at the time of intervention. At 1 month follow-up, he developed congestive heart failure with a further decline in EF to 25\%. Although the IMH was resolving, the left ventricular apex had ballooned out. At 3 months, he was rehospitalised with a storm of ventricular tachycardia, further deterioration in EF with an apical aneurysm, and eventually passed away.
"""

example2 = """
**Discharge Summary**

**Patient Information:**
- **Name:** [Patient Name]
- **Age:** 74 years
- **Gender:** Male

**Admission Date:** [Admission Date]  
**Discharge Date:** [Discharge Date]  
**Attending Physician:** [Physician Name]  

**Diagnosis:**
- Complete occlusion of proximal left anterior descending artery
- Intramyocardial hematoma (IMH)
- Congestive heart failure
- Ventricular tachycardia

**Procedure:**
The patient underwent primary percutaneous coronary intervention (pPCI) for a completely occluded proximal left anterior descending artery. During the procedure, the no-reflow phenomenon was encountered, and management included administration of diltiazem and nicorandil.

**Post-Procedure Findings:**
A follow-up echocardiogram conducted the day after the procedure indicated the presence of an intraparietal echolucent apicolateral neocavitation, consistent with an intramyocardial hematoma (IMH). The patient's ejection fraction (EF) was noted to be 30%, a decline from 45% recorded during the intervention.

**Follow-Up:**
At the one-month follow-up, the patient developed congestive heart failure, with further deterioration in EF to 25%.Although the IMH showed signs of resolution, there was notable ballooning of the left ventricular apex.

**Rehospitalization:**
At three months post-procedure, the patient was rehospitalized due to a storm of ventricular tachycardia and additional decline in EF, accompanied by the development of an apical aneurysm.

**Outcome:**
Despite medical interventions, the patient ultimately passed away.

**Recommendations:**
- Continued monitoring and management of cardiac function.
- Consideration for advanced heart failure therapies.

**Prepared by:** [Your Name]  
**Date:** [Date]
"""

# %%
# Load a generative model
import torch
from transformers import pipeline

model_id = "/gpfs/projects/bsc14/abecerr1/hub/models--meta-llama--Llama-3.2-3B-Instruct/snapshots/0cb88a4f764b7a12671c53f0838cd831a0843b95"
pipe = pipeline(
    "text-generation",
    model=model_id,
    torch_dtype=torch.bfloat16,
    # device="cuda",
    device_map="auto",
)

terminators = [
    pipe.tokenizer.eos_token_id,
    pipe.tokenizer.convert_tokens_to_ids("<|eot_id|>")
]
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Device set to use cuda:0

# %%
def llm_abv_extractor(pipe, text):

    instruction = "Create a dictionary with the abbreviations and their corresponding full form if found in the text."
    instruction += " The dictionary should be in the format: {'<abbreviation>': '<full form>'}."
    instruction += "Don't add anything else or any comments. Apply it only to abbreviations. Make sure to include all of them and that they are really abbreviations."
    instruction += "If no abbreviations are found, return an empty dictionary."
    instruction += "Negative examples: 'The patient was diagnosed with diabetes mellitus.' should return an empty dictionary."
    prompt = text
    # print(prompt)

    messages = [
        {
            "role": "system",
            "content": instruction
        },
        {
            "role": "user",
            "content": prompt
        }
    ]

    outputs = pipe(
                    messages,
                    max_new_tokens=512,
                    temperature=0.01,
                    repetition_penalty=1.2,
                    # do_sample=True,
                    eos_token_id=terminators,
                    pad_token_id=pipe.tokenizer.eos_token_id,
                )

    
    return outputs[0]["generated_text"][-1]["content"]

# %%
abbr_dict = llm_abv_extractor(pipe, example1)
print(abbr_dict)
# Out:
# {'pPCI': 'primary percutaneous coronary intervention',
# 'IMH': 'intrap myocardial hematoma'}

# %%
import pandas as pd
import os
from src.data import files_to_df

SOURCE_PATH_ORIG = "data/1_original/txt"
SOURCE_PATH_GEN = "data/2_generated/2step_transformation_dt4h_GPT4omini/en"

def create_pairs(path_orig, path_gen):

    df_gen = files_to_df(path_gen)
    df_gen["filenameid"] = df_gen["filenameid"].str.replace("_transformed_step1", "")

    df_orig = files_to_df(path_orig)
    df_pairs = df_orig.merge(df_gen, on="filenameid", suffixes=("_orig", "_gen"))
    # assert len(df_pairs) == N_EXPECTED_SAMPLES, f"Expected {N_EXPECTED_SAMPLES} samples, got {len(df_pairs)}"

    df_pairs.rename(columns={"text_orig": "clinical_case", "text_gen": "discharge_summary"}, inplace=True)
    return df_pairs

df_pairs = create_pairs(SOURCE_PATH_ORIG, SOURCE_PATH_GEN)

# %%
from tqdm import tqdm
tqdm.pandas(desc="Processing")
import json

# df_pairs["abbr_dict"] = df_pairs["clinical_case"].progress_apply(lambda x: llm_abv_extractor(pipe, x))

#### Generate abbreviation dictionary
# df_pairs["abbr_dict"] = df_pairs["clinical_case"].progress_apply(lambda x: llm_abv_extractor(pipe, x))

# import ast
# import json
# ls_dicts_out = []

# for i, row in tqdm(df_pairs.iterrows()):
#     try:
#         abbr_dict = ast.literal_eval(row["abbr_dict"])
#     except:
#         try:
#             abbr_dict = eval(row["abbr_dict"])
#         except:
#             try:
#                 abbr_dict = json.loads(row["abbr_dict"])
#             except:
#                 print(f"Error processing row {i}: {row['abbr_dict']}")
#                 continue
            
#     ls_dicts_out.append(abbr_dict)        
    
# abbv_dict = {}

# for i in ls_dicts_out:
#     abbv_dict.update(i)
    
# d_out = {}
# for k, v in abbv_dict.items():
#     if k is not None and v is not None:
#         if len(list(set(k.lower().split()) & set(v.lower().split()))) == 0:
#             if len(k.split()) <= 2:
#                 d_out[k] = v
        
# json.dump(d_out, open("data/5_abbreviations/cardio_abbv.json", "w"), indent=4)

d_abbrev = json.load(open("data/5_abbreviations/cardio_abbv.json", "r"))
d_abbrev
# Out:
# {'ECG': 'electrocardiogram',
#  'IgG': 'Immunoglobulin G',
#  'HHT': 'Hereditary Hemorrhagic Telangiectasia',
#  'NYHA': 'New York Heart Association',
#  'NKF': 'National Kidney Foundation',
#  'STEMI': 'ST-Segment Elevation Myocardial Infarction',
#  'PCI': 'Percutaneous Coronary Intervention',
#  'LAD': 'Left Anterior Descending',
#  'RCA': 'right coronary artery',
#  'CX': 'Circumflex',
#  'IVABRADEINE': 'Anti-Arrhythm Drug Ivabradine',
#  'CRX': 'chest radiograph',
#  'HRCT': 'High-Resolution Computed Tomography',
#  'PP': 'pleural plaques',
#  'LVEF': 'Left Ventricular Ejection Fraction',
#  'CO': 'Carbon Monoxide',
#  'Fr': 'French unit',
#  'iVAC2L': 'Intra-Aortic Counterpulsation Device',
#  'HF': 'Heart Failure',
#  'LVD': 'Left Ventricular Assist Device',
#  'LVAD': 'Left Ventricular Assist Device',
#  'INR': 'International Normalized Ratio',
#  'CMV': 'Cytomegalovirus',
#  'MTA': 'Thrombotic Microangiopathy',
#  'GSA': '',
#  'HIV': 'Human Immunodeficiency Virus',
#  'PA': 'Pulmonary Artery',
#  'PGML': 'picogolulin-like protein',
#  'BPN': 'B-type Natriuretic Peptide',
#  'TRO': 'troponin',
#  'BUN': 'Blood Urea Nitrogen',
#  'CREE': 'creatinine',
#  'SD': 'selective dorsal',
#  'VA-ECMO': 'Ventricular Assist Device Extracorporeal Membrane Oxygenation',
#  'HD': 'hemodialysis',
#  'MRC': 'Medical Research Council',
#  'RBBB': 'Right Bundle Branch Block',
#  'SAS': 'Sleep Apnea Syndrome',
#  'NNTbP': 'N-terminal Prohormone of Brain Natriuretic Peptide',
#  'PVL': 'Posterior Leaflet',
#  'ABI': 'Ankle-Brachial Index',
#  'LV': 'Left Ventricle',
#  'DTA': 'Descending Thoracic Aorta',
#  'Haemostasis': 'Stopping bleeding',
#  'Redivac': 'Redevac drain (a type of drainage tube)',
#  'Transpulmonary': 'Across the lungs',
#  'thrombus': 'blood clot',
#  'ENT': 'Ear, Nose and Throat',
#  'SVC': 'Superior Vena Cava',
#  'PPCM': 'Peripartum Cardiac Dysfunction',
#  'PCCM': '',
#  'PE': 'Pulmonary Embolism',
#  'DVT': 'Deep Vein Thrombosis',
#  'HVAD': '',
#  'RP': 'reentrant paroxysmal',
#  'RRT': 'renal replacement therapy',
#  'R-CHOP': 'Rituximab plus Cyclophosphamide, Doxorubicin, Hydroxydaunorubicin, Prednisone',
#  'GEMOX': 'gemcitabin, oxaplatin',
#  'CIPO': 'Congestive Ileus Postoperative',
#  'II-10': 'Japan Coma Scale score',
#  'HbA1c': 'glycosylated hemoglobin A1c',
#  'NSCLC': 'Non-Small Cell Lung Carcinoma',
#  'cT3N2M1a': 'Stage IIIA non-small cell lung cancer',
#  'CT': 'Computed Tomography',
#  'MR': 'Mitral Regurgitation',
#  'PVR': 'Patent Ventricular Septal Defect',
#  'OHT': 'Orthotopic Heart Transplantation',
#  'HLT': 'Heart-Lung Team',
#  'TrEVAD': 'Total Externally-Ventilated Artificial Device',
#  'C.X.Z': 'Constrictive Pericarditis',
#  'RHF': 'Right Heart Failure',
#  'CP': 'Constrictive Pericarditis',
#  'DIABETES MELLITUS': '',
#  'BPM': 'Beats Per Minute',
#  'NYHA FC': 'New York Heart Association Functional Class',
#  'ASD': 'Atrial Septal Defect',
#  'CML': 'Chronic Myelogenous Leukemia',
#  'COPD': 'Chronic Obstructive Pulmonary Disease',
#  'CTA': 'Computed Tomography Angiography',
#  'LCH': 'Lymphangioleiomyomatosis',
#  'MDS': 'Myelodysplastic Syndrome',
#  'dyspnea': 'difficulty breathing',
#  'RVD': 'Right Ventricular Dysfunction',
#  'SARS-CoV-2': 'Severe Acute Respiratory Syndrome Coronavirus 2',
#  'TEE': 'Transesophageal Echocardiography',
#  'BP': 'Blood Pressure',
#  'ED': 'Emergency Department',
#  'A0P2G2': 'After 0 Postpartum Years 2 Gestations 2',
#  'MD': 'Medtronic',
#  'DIMERS': 'D-dimer',
#  'NTBNP': 'N-terminal pro b-type natriuretic peptide',
#  'LVP': 'Left Ventricular Pressure',
#  'LVH': 'left ventricular hypertrophy',
#  'CPTA': 'Computed Tomography Pulmonary Angiography',
#  'US': 'ultrasound',
#  'BNP': 'Brain Natriuretic Peptide',
#  'CRBBB': 'Complete Right Bundle Branch Block',
#  'U/mL': 'per million liters',
#  'AVB': 'complete atrioventricular block',
#  'BHL': 'Bilateral Hilar Lymphadenopathy',
#  'TBLB': 'Transbronchial Lung Biopsy',
#  'LVDd': 'left ventricular diameter',
#  'LVDs': 'Left Ventricular End-Systolic Dimension',
#  'IVSd': 'interventricular septum diameter',
#  'LVPWd': 'Left Ventricular Posterior Wall Thickness',
#  'HBP': 'High Blood Pressure',
#  'ADHD': 'attention-deficit/hyperactivity disorder',
#  'GDMT': 'guideline-directed medical therapy',
#  'IgA': 'Immunoglobulin A',
#  'WT': 'Wilms tumor',
#  'ARDS': 'Acute Respiratory Distress Syndrome',
#  'COVID-19': 'Coronavirus disease 2019',
#  'TQC': 'Corrected QT Interval',
#  'STEE': 'transthoracic echocardiography',
#  'RVEF': 'right ventricular ejection fraction',
#  'ARB': 'Angiotensin Receptor Blocker',
#  'BPNP': 'N-Terminal Pro-Brain Natriuretic Peptide',
#  'BB': 'Beta Blocker',
#  'CRT-D': 'Cardiac Resynchronization Therapy Defibrillator',
#  'CRT': 'Cardiac Resynchronization Therapy',
#  'ESLD': 'End-stage liver disease',
#  'MELD': 'Model for End-Stage Liver Disease',
#  'LT': 'Liver Transplant',
#  'SBP': 'Spontaneous Bacterial Peritonitis',
#  'CHADS-VASC': 'congestive heart failure, hypertension, age ≥ 75 years, diabetes, stroke/TIA, vascular disease, renal dysfunction, cardiopulmonary disease, peripheral artery disease, cerebrovascular disease',
#  'atrial fibrillation': 'abnormal heart rhythm originating in the upper chambers',
#  'rheumatoid arthritis': 'autoimmune disorder causing joint pain',
#  'idiotypic pneumonitis': 'rare lung inflammation',
#  'G2P2': 'Gravida 2, Para 2',
#  'Orthopnea': 'Short breathing while lying down',
#  'EKG': 'Electrocardiogram',
#  'TTE': 'Transthoracic echocardiogram',
#  'CXR': 'Chest X-ray',
#  'LCA': 'Left Coronary Artery',
#  'MLC': 'Main Left Coronary Artery',
#  'JVP': 'Jugular venous pressure',
#  'LGE': 'late gadolinium enhancement',
#  'MPG': 'maximal perfusion gradient',
#  'AVAi': 'aortic valve annulus area',
#  'SVi': 'stroke volume index',
#  'TAPSE': 'Transthoracic Echocardiographic Pulmonary Valve Assessment',
#  'CES': 'Cesarean Section',
#  'CRP': 'C-reactive protein',
#  'MRI': 'Magnetic Resonance Imaging',
#  'IUGR': 'not mentioned',
#  'TPN': 'transfusion not necessary but possible given recent surgeries',
#  'SARS-COV-2': 'Severe acute respiratory syndrome coronavirus 2',
#  'MLWHFQ': 'Minnesota Living with Heart Failure Questionnaire',
#  'ECHO': 'Echocardiogram',
#  'CRP-HS': 'C-reactive protein - high sensitivity',
#  'H&E': 'hematoxylin and eosin',
#  'II/VI': 'Second Heart Sound',
#  'k/uL': 'per thousand microliters per liter',
#  'M4': 'Middle Cerebral Artery',
#  'AATS': 'American Association of Thoracic Surgery',
#  'aHA': 'American Heart Association',
#  'ACS': 'Acute Coronary Syndrome',
#  'CVD': 'Cardiovascular Disease',
#  'EURO-II': 'European Society of Cardiology European Society of Cardiology (ESC) risk model',
#  'HDL-C': 'high-density lipoprotein cholesterol',
#  'STS': 'Stanford Type of Surgery',
#  'PD': 'Peritoneal Dialysis',
#  'BPS': 'Blood Pressure Surveillance',
#  'HDD': 'Home Daily Haemodialysis',
#  'UFR': 'Ultrafiltration Rate',
#  'IABP': 'Intra-Aortic Balloon Pump',
#  'ECMO': 'extracorporeal membrane oxygenation',
#  'TandemHeart': 'percutaneous ventricular assist device',
#  'TAVI': 'Transcatheter Aortic Valve Implantation',
#  'LOTUS': 'Low Output Turbulex Surgical Bioprosthetic Valves',
#  'Cefazolin': 'A type of antibiotic used as an antibiotic prophylaxis',
#  'MRSE': 'Methicillin-Resistant Staphylococcus Epidermidis',
#  'AHF': 'Acute Heart Failure',
#  'S3': 'third heart sound',
#  'HCQ': 'Hydroxychloroquine',
#  'Ecg': 'Electrocardiogram',
#  'RU': 'Radioimmunoassay units',
#  'IU/ml': 'International Units per milliliter',
#  'Ru': 'Radioactive unit',
#  'LVT': 'left ventricular thrombus',
#  'LVESD': 'Left Ventricular End-Systolic Dimension',
#  'LVEDS': 'Left Ventricular End-Systolic Diameter',
#  "Kloiber's cups": 'absent on radiographs',
#  'PCH': 'Post-Cesarean Hemorrhage',
#  'PPH': 'Postpartum Hemorrhage',
#  'CPAP': 'Continuous Positive Airway Pressure',
#  'frusemide': 'Furosemide',
#  'TSH': 'thyroid-stimulating hormone',
#  'HAART': 'Highly Active Antiretroviral Therapy',
#  'INN-etravirine': 'Indinavir',
#  'CYP3A4': 'Cytochrome P450 family 3, Subfamily A, Polypeptide 4',
#  'G3P3': 'Gravida 3, Para 3',
#  'Hb': 'hemoglobin',
#  'LDH': 'Lactate Dehydrogenase',
#  'LVEDD': 'Left Ventricular End-Diastolic Dimension',
#  'O G': 'Outflow Gradients',
#  'AC': 'Adriamycin (doxorubicin) + Cyclophosphamide',
#  'CTRCRd': 'Cardiac Toxicity Related Complication',
#  'LVIDD': 'Left Ventricular Internal Diameter at End-Diastole',
#  'CIAA': 'Common Iliac Artery Aneurysm',
#  'IVC': 'inferior vena cava',
#  'EVAR': 'Endovascular Repair of the Abdominal Aorta',
#  'ADA': 'Adenosine Deaminase',
#  'OSA': 'Obstructive Sleep Apnea',
#  'dyspnoea': 'difficulty breathing',
#  'hypertension': 'high blood pressure',
#  'lipid': 'hyperlipidaemia',
#  'bnp': 'N-terminal pro b-type natriuretic peptide',
#  'HCM': 'Hypertrophic Cardiomyopathy',
#  'TRR': 'Transthyretin',
#  'ATTR': 'Amyloid Transthyretin',
#  'ATRP': 'Amyloid Trapping Protein',
#  'ATTP': 'Amyloid Transporting Protein',
#  'SCAI': 'Systematic Coronary Angiography',
#  'INTERMACS': 'Institute of Medicine for Clinical Advancement in Cardiac Support',
#  'DOUBATAMINE': 'Medication used to treat low blood pressure',
#  'P2': 'Second Heart Sound',
#  'HFrEF': 'heart failure with reduced ejection fraction',
#  'DES': 'Drug Eluting Stent',
#  'OCT': 'optical coherence tomography',
#  'POCUS': 'Point-of-Care Ultrasound',
#  'Tricento': 'Tricenco transcatheter heart valve',
#  'VECMR': 'Venous Echo Cardiogram Magnetic Resonance',
#  'MPS': 'Mucopolysaccharidosis',
#  'ARSB': 'Arylsulfatase B',
#  'MPSVII': 'Mucopolysaccharidosis Type VII',
#  'LV-GLS': 'Left Ventricular Global Longitudinal Strain',
#  'MCA': 'Middle Cerebral Artery',
#  'PTT': 'partial thromboplastin time',
#  'AS': 'aortic stenosis',
#  'SAVR': 'Transcatheter Aortic Valve Replacement',
#  'EUROSCORE': 'European System for Cardiac Operative Risk Evaluation Score',
#  'TF': 'Transfemoral',
#  'TS': 'Torsades de Pointes Syndrome',
#  'Ao-TAVI': 'Aortic Transcatheter Valve Implantation',
#  'Afib': 'Atrial Fibrillation',
#  'WBC': 'White Blood Cell Count',
#  'LBBB': 'left bundle branch block',
#  'CRTD': 'Cardiac Resynchronization Therapy-Defibrillator',
#  'B+': 'Blood Group',
#  'ASAT': 'Aspartate Aminotransferase',
#  'ALAT': 'Alanine Transaminase',
#  'PAL': 'Prothrombin Time Activated Partial',
#  'BT': 'Beta-Thromboglobulin',
#  'PLQ': 'Patient Location Query',
#  'AHI': 'apnea-hypopnea index',
#  'FLA': 'Florida',
#  'MN': 'minutes',
#  'ACCF': 'American College of Cardiology',
#  'RWC': 'Right Ventricular Complex',
#  'LMCA': 'Left Main Coronary Artery',
#  'LCX': 'Left Circumflex Artery',
#  'do': 'doubtamine',
#  'kpa': 'kilopascals',
#  'mL': 'milliliters',
#  'NT-proBNP': 'N-terminal Pro B-type Natriuretic Peptide',
#  'ACE': 'Angiotensin-Converting Enzyme',
#  'NSE': 'Neuron-Specific Enolase',
#  'AJCC': 'American Joint Committee on Cancer',
#  'RVF': 'Right Ventricular Failure',
#  'ccTGA': 'Conotruncal Congenital Heart Anomaly',
#  'DDD-pacemaker': 'Dual Chamber Defibrillating Pacemaker',
#  'CRT-P': 'Cardiac Resynchronization Therapy - Pacing',
#  'sRV': 'Right Ventricle',
#  'TVR': 'tricuspid valve repair',
#  'AMI': 'acute myocardial infarction',
#  'CKD': 'Chronic Kidney Disease',
#  'ST': 'Short Term',
#  'HAP': 'Hospital Acquired Pneumonia',
#  'C-RP': 'C-Reactive Protein',
#  'TA': 'Takayasu arteritis',
#  'RSH': 'Rectus Sheath Hematoma',
#  'CAF': 'Coronary Artery Fistula',
#  'ADHFrEF': 'Acute Decompensated Heart Failure with Reduced Ejection Fraction',
#  'MS': 'Mitral Sound',
#  'DMD': 'Becker muscular dystrophy',
#  'DMN': 'Desminopathy',
#  'SP': 'Systolic Pressure',
#  'kg': '',
#  'bpm': 'beats per minute',
#  'HSCT': 'Hematopoietic Stem Cell Transplant',
#  'RV': 'Right Ventricle',
#  'COP': 'Chronic Obstructive Pulmonary Disease',
#  'GP': 'general practitioner',
#  'SE': 'standard error',
#  'DCM': 'Dilated Cardiomyopathy',
#  'PCWP': 'Pulmonary Capillary Wedge Pressure',
#  'RVSWI': 'right ventricular stroke work index',
#  'CVP': 'Central Venous Pressure',
#  'APGAR': 'American Pain Society-Giving Analgesia Responsibly',
#  'NICU': 'Neonatal Intensive Care Unit',
#  'VSD': 'Ventricular Septal Defect',
#  'IV': 'Intravenous',
#  'MMR': 'Mitral Regurgitation',
#  'LVF': 'Left Ventricular Failure',
#  'RV/LV': 'Right Ventricular-to-Left Ventricular',
#  'PAS': 'Pulmonary Atresia Sequence',
#  'RVT': 'right ventricular dysfunction',
#  'MVo2': 'Mixed Venous Oxygenation',
#  'Dobutamine': 'dopamine infusion used to increase cardiac output',
#  'RAP': 'right atrial pressure',
#  'SARS-CoV-2 RT-PCR': 'Reverse Transcription Polymerase Chain Reaction',
#  'Methimazole': 'Methylthioazolothione',
#  'Metoprolol': 'beta blocker',
#  'STA': 'aspartate aminotransferase',
#  'LFT': '',
#  'CPR': 'Cardiopulmonary Resuscitation',
#  'TNTB': 'N-terminal prohormone of brain natriuretic peptide',
#  'PVC': 'premature ventricular contraction',
#  'GWE': 'glomerular filtration rate equivalent',
#  'GCW': 'Global Contractile Work',
#  'GWU': 'global wall uniformity',
#  'LVEDP': 'Left Ventricular End-Diastolic Pressure',
#  'TIMI': 'thrombolysis in myocardial infarction',
#  'LVEDF': 'left ventricular ejection fraction',
#  'CAE': 'cesarean delivery',
#  'SPAO': 'slanting position of the fetus',
#  'HR': 'Heart Rate',
#  'GH': 'Growth hormone',
#  'IGF-1': 'Insulin-like growth factor 1',
#  'BMP': 'Blood Type',
#  'pg/mL': 'picograms per milliliter',
#  'mmHg': 'millimeters of mercury',
#  'L/min': 'liters per minute',
#  'cmH2O': 'centimetres of water',
#  'SRV': 'Superior Residual Vent',
#  'HLA': 'Human Leukocyte Antigen',
#  'POD': 'Post-Operative Day',
#  'haemodialysis': 'hemodialysis',
#  'CAPS': 'Cryopyrin-Associated Periodic Syndromes',
#  'SS-OCT': 'Spectral-Spatial Optical Coherence Tomography',
#  'NTG': 'Normal Troponin Levels',
#  'CNC': 'Cardiac Myxoma',
#  'VT': 'Ventricular Tachycardia',
#  'D2': 'Second Diagonal',
#  'OM1': 'First Obtuse Marginal',
#  'DI': 'Diuretics',
#  'BIV': 'Biventricular Pacing',
#  'RVEDP': 'Right Ventricular End Diastolic Pressure',
#  'EPO': 'epoetin',
#  'ESC': 'European Society of Cardiology',
#  'ERS': 'European Respiratory Society',
#  'CCF': 'Congestive Cardiac Failure',
#  'ALT': 'Alanine Transaminase',
#  'SAR-CoV-2': 'Severe Acute Respiratory Coronavirus 2',
#  'HS': 'Hidradenitis Suppurativa',
#  'IRBP': '',
#  'SPLM': '',
#  'RBC': 'red blood cell',
#  'DBS': '',
#  'RV FAC': 'Right Ventricular Fractional Area Change',
#  'CAT': 'COPD Assessment Test',
#  'SpO2': 'Spontaneous oxygen saturation',
#  'G1P0': 'Gravida one, Para zero',
#  'Rh+': 'Rhesus positive',
#  'AVD': 'Atrioventricular Delay',
#  'DDD': 'Dual-Chamber Demand Pacing',
#  'HeartMate': 'Left Ventricular Assist Device',
#  'LVEDV': 'Left Ventricular End Diastolic Volume',
#  'LVESV': 'Left Ventricular End-Systolic Volume',
#  'LVEF%': 'Left Ventricular Ejection Fraction Percentage',
#  'AV': 'Atrioventricular',
#  'EF': 'ejection fraction',
#  'TVLD': 'Tricuspid Valve-Lung Dynamics',
#  'CABG': 'coronary artery bypass grafting',
#  'MYBPC3': 'myosin-binding protein c-3',
#  'CMD': 'Coronary Microvascular Disease',
#  'HFpEF': 'Heart Failure with Preserved Ejection Fraction',
#  'dt': '',
#  'la': 'left atrium',
#  'mmhg': 'millimeters of mercury',
#  'AVM': 'Arteriovenous Malformation',
#  'AF': 'Atrial Fibrillation',
#  'VO2': 'oxygen uptake',
#  'acei-ae': 'angiotensin-converting enzyme inhibitor-induced angioedema',
#  'RA': 'Right Atrium',
#  'ANA': 'Antinuclear Antibody',
#  'APNCA': 'Anti-Neutrophil Cytoplasmic Antibodies',
#  'BLSB': 'Left Bundle Branch Block',
#  'CRA': 'C-Reactive Protein',
#  'DNA': 'Deoxyribonucleic Acid',
#  'RAS': 'Renal Artery Stenosis',
#  'Pazopanib': 'a type of anti-cancer drug',
#  'CPB': 'Cardiopulmonary Bypass',
#  'ILAC': 'Iliac',
#  'TV': 'Tricuspid Valve',
#  'Qp/Qs': 'Quantitative Pulmonary/Systemic Flow Ratio',
#  'TAPVC': 'Total Anomalous Pulmonary Venous Connection',
#  'ThreeV': 'Three Vessels',
#  'SA': 'Sleep Apnea',
#  'CSR': 'Central Sleep Apnea',
#  'NREM': 'Non-Rapid Eye Movement',
#  'REM': 'Rapid Eye Movement',
#  'APTT': 'Activated Partial Thromboplastin Time',
#  'C-Reactive Protein': 'CRP',
#  'VGAM': 'Ventricular Great Artery Malformation',
#  'AVS': 'Arteriovenous Shunt',
#  'AFib': 'Paroxysmal Atrial Fibrillation',
#  'NTproBNP': 'N-terminal Pro B-Type Natriuretic Peptide',
#  'LAVI': 'left atrial volume index',
#  'ACEI': 'Angiotensin-Converting Enzyme Inhibitors',
#  'β-Blocker': 'Beta Blocker',
#  'MRA': 'Mineralocorticoid Receptor Antagonist',
#  'RCC': 'Renal Cell Carcinoma',
#  'RVFAC': 'Right Ventricular Fractional Area Change',
#  'AP': 'Atrioventricular',
#  'LVEDVi': 'left ventricular end-diastolic volume index',
#  'CHF': 'Congestive Heart Failure',
#  'HM': 'HeartMate',
#  'MAS': 'Macrophagic Activation Syndrome',
#  'DSE': 'Dobutamine Stress Echocardiogram',
#  'RV-PGD': 'Right Ventricular Post-Transplant Dysfunction',
#  'Dob': 'Dobutamine',
#  'PFS': 'Periodic Fever Syndrome',
#  'IHD': 'Ischemic Heart Disease',
#  'MBCK': 'Muscle Brain Creatine Kinase',
#  'GCM': 'Granulomatous Myocarditis',
#  'ADHF': 'acute decompensated heart failure',
#  'CTO': 'Chronically Occluded',
#  'MM': 'Marginal',
#  'OM': 'Obtuse Marginal',
#  'AL': 'Amyloid Light Chain',
#  'EBU': 'Endobrush Universal',
#  'FMR': 'Functional Mitral Regurgitation',
#  'IS': 'Ischemic',
#  'SARSCoV2': 'Severe Acute Respiratory Syndrome Coronavirus 2',
#  'RBSI': 'Respiratory Shallow Breathing Index',
#  'ST-ELEVATION': 'Elevated level of oxygen above atmospheric pressure',
#  'V1-V6 Derivations': 'Electrocardiographic leads located on different parts of the body',
#  'Hypokinesia': 'Reduced movement of the heart muscles',
#  'Culprit Lesion': 'Blockage in one specific area of the coronary arteries',
#  'LVFE': 'Left Ventricular Function Efficiency',
#  'P. aerguinosa': 'Pseudomonas aeruginosa',
#  'SARSCoV-2 RT-PCR': 'reverse transcriptase-polymerase chain reaction for SARS-CoV-2 RNA',
#  'ITU': 'intensive treatment unit',
#  'EFG': 'ejection fraction',
#  'Lcx': 'left circumflex coronary artery',
#  'UTB': 'dysfunctional uterine bleeding',
#  'MENR': 'menorrhagia',
#  'SPON': 'splenomegaly not mentioned but possible based on other findings',
#  'DBSL': 'dysuria not present but may have been considered',
#  'BPDN': 'paroxysmal nocturnal dyspnea not present',
#  'ECCO': 'exertional chest congestion not present',
#  'TR': 'tricuspid regurgitation',
#  'SR': 'sinus rhythm',
#  'MV': 'Mean Ventricular Systolic Pressure',
#  'TPV': 'Tricuspid Valve Prosthesis',
#  'CRF': 'chronic renal failure',
#  'GLA': 'Glucosidase alpha',
#  'IF': 'Immunofluorescence',
#  'AAT': 'alpha-1-acid glycoprotein',
#  'DVD': 'ventricular diverticulum',
#  'IU': 'International unit',
#  'LDL-C': 'low-density lipoprotein cholesterol',
#  'RUQ': 'right upper quadrant',
#  'RVH': 'right ventricular hypertrophy',
#  'SB': 'silent breath',
#  'SCR': 'serum creatinine ratio',
#  'SDS': 'sacral nerve stimulation',
#  'SGLT': 'sodium-glucose linked transporter',
#  'SMRM': 'single photon emission computed tomography',
#  'SVCT': 'slow ventricular conduction time',
#  'TCHOL': 'total cholesteryl esters',
#  'THB': 'thoracic inlet',
#  'THR': 'thalassemia',
#  'TIBC': 'transferrin binding capacity',
#  'TPS': 'Tumor protein p53',
#  'USG': 'ultrasound',
#  'VeGF': 'vascular endothelial growth factor',
#  'MCV': 'Mean Corpuscular Volume',
#  'TTroponins': 'Troponins',
#  'ng/mL': 'nanograms per milliliter',
#  'SV': 'Systemic Ventricle',
#  'BVP': 'B-type Natriuretic Peptide',
#  'CCTGA': 'Congenital Cardiovascular Defects Group A',
#  'dextrocardia': 'Position where the heart is located on the right side of the chest',
#  'PAPVR': 'Partial Anomalous Pulmonary Venous Return',
#  'RSV': 'Respiratory Syncytial Virus',
#  'Covid-19': 'Coronavirus Disease 2019',
#  'ESR': 'Erythrocyte Sedimentation Rate',
#  'AST': 'Aspartate Transaminase',
#  'NSTEMI': 'Non-ST-Elevation Myocardial Infarction',
#  'PCIs': 'Percutaneous Coronary Interventions',
#  'AORR': 'aortic regurgitation',
#  'HT': 'Heart Transplant',
#  'αL-iduronidase': 'human recombinant',
#  'EFT': 'Ejection Fraction',
#  'Z': 'z-score',
#  'CCTA': 'Cardiac Computed Tomography Angiography',
#  'SPNO2': 'Spontaneous Pulmonary Notching on Oxygen Saturation',
#  'CTR': 'Cardiothoracic Ratio',
#  'eGFR': 'Estimated Glomerular Filtration Rate',
#  'E/A': 'Early Diastolic Velocity',
#  'DT': 'days since treatment',
#  'AAC': 'atypical aortic coarctation',
#  'FIBRO': 'fiberoptic bronchoscopy',
#  'BAL': 'bronchoalveolar lavage',
#  'EBS-TBNA': 'endobronchial ultrasound-guided transbronchial needle aspiration',
#  'ICD': 'Implantable Cardioverter Defibrillator',
#  'SAM': 'systolic anterior motion',
#  'TEER': 'Transcatheter Edge-to-Edge Repair',
#  'U/L': 'Units per liter',
#  'mm3': 'cubic millimeters',
#  'mg/dL': 'milligrams per deciliter',
#  'RVOT': 'Right Ventricular Outflow Tract',
#  'Oken': 'Performance Status (Oken et al.)',
#  'GOLD': 'Global Initiative for Chronic Obstructive Lung Disease',
#  'DIEIs': 'Drug-Induced Esophageal Injury',
#  'LA': 'Left Atrium',
#  'TEVAR': 'Transcatheter Endovascular Repair',
#  'MG': 'Magnesium',
#  'ICI': 'immunotherapy',
#  'IgM': 'Immunoglobulin M',
#  'AVR': 'aortic valve replacement',
#  'LVDAS': 'Left Ventricular Assist Device Surgery',
#  'DNA-diagnosics': 'DNA diagnostics',
#  'EMSEMPLE_VEP': 'EMSEMPLE VEP analysis',
#  'HFE': 'Hereditary Hemochromatosis Gene',
#  'NHS': 'National Health Service',
#  'SARCOMERIC': 'sarcomerotic',
#  'AVF': 'Arteriovenous Fistula',
#  'ICU': 'Intensive Care Unit',
#  'PeV-A': 'Poxvirus Alastrim Virus Type A',
#  'NATs': 'Neutralizing Antibodies Tests',
#  'QRS': 'Quadruple Response',
#  'DDR': 'Double-chamber dual-response pacing',
#  'Biotronik': 'Manufacturer of ICD Device',
#  'SprintQuattro': 'Type of RV Defibrillation Lead',
#  'Medtronic': 'Manufacturer of CRT-D Device',
#  'Torsemide': 'Loop Diuretic Medication',
#  'Perindopril': 'Angiotensin-Converting Enzyme Inhibitor Medication',
#  'SVT': 'supraventricular tachycardia',
#  'PRBC': 'packed red blood cells',
#  'DDLT': 'deceased donor liver transplant',
#  'CF': 'cubic feet',
#  'ACT': 'Activated Clotting Time',
#  'Hypertension': 'High Blood Pressure',
#  'LIP': 'Hyperlipidemia',
#  'orthopnea': 'breathing difficulty when lying down',
#  'worsening dyspnea': 'difficulty breathing during exercise',
#  'soars': 'open wounds without pus',
#  'cellulitis': 'a bacterial infection of the skin and subcutaneous tissue',
#  'Kaposi-Stemmer sign': 'a clinical finding indicative of poor circulation',
#  'EA': 'Electrolyte Abnormality',
#  'AAI': 'Atrial Activity Interval',
#  'DCMP': 'Dilated Cardiomyopathy',
#  'AMP': 'Amplifier',
#  'CMP': 'Cardiomyopathy',
#  'DIAG': 'Diagnosis',
#  'LVC': 'Left Ventricular Catheterization',
#  'RHC': 'right heart catheterization',
#  'IDHA': 'Chronic Severe Iron Deficiency Anemia',
#  'PH': 'Pulmonary Hypertension',
#  'HOCM': 'Hypertrophic Obstructive Cardiomyopathy',
#  'b.i.d': 'twice daily',
#  'EI-LBBB': 'End-Insufficiency Left Bundle Branch Block',
#  'LVOTO': 'Left Ventricular Outflow Tract Obstruction',
#  'FD': 'Fabry Disease',
#  'FEU': 'Fibrinogen Equivalent Units',
#  'anorexia nervosa': 'An eating disorder characterized by restricted food intake leading to significantly low body weight.',
#  'anemia': 'A condition where the number of red blood cells or amount of hemoglobin in the blood is lower than normal.',
#  'IVD': 'Intravascular Device',
#  'SVR': 'Severe Valvular Regurgitation',
#  'CRS': 'Cardiac Risk Syndrome',
#  'AKI': 'Acute Kidney Injury',
#  'LVV': 'Left Ventricular Valve',
#  'LAVV': 'Left Atrioventricular Valve',
#  'asthenia': 'weakness',
#  'bmi': 'body mass index',
#  'st': 'smoker',
#  'nhs': 'none',
#  'mur': 'heart murmur',
#  'dermatol': 'skin condition',
#  'neurology': 'nerve disorder',
#  'articol': 'joint disease',
#  'rct': 'respiratory tract infection',
#  'hypertn': 'high blood pressure',
#  'glaucom': 'eye condition',
#  'diverticul': 'intestinal blockage',
#  'Bhepat': 'chronic viral hepatitis',
#  'erectile dysfunction': 'impotence',
#  'pcr': 'polymerase chain reaction',
#  'Troponin': 'enzyme marker',
#  'Bnp': 'brain natriuretic peptide',
#  'Hmdp': 'bone scanning agent',
#  'amylod': 'amyloid deposit',
#  'CDS': 'CD system',
#  'FLC': 'free light chain',
#  'N': 'normotensive',
#  'MI': 'myocardial infarction',
#  'Po2': 'partial pressure of oxygen',
#  'Pco2': 'partial pressure of carbon dioxide',
#  'SARs': 'severe acute respiratory distress syndrome',
#  'CAHD': 'Coronary Atherosclerotic Heart Disease',
#  'NIDDM': 'Non-insulin-dependent Diabetes Mellitus',
#  'CA': 'coronary angiography',
#  'CMR': 'Cardiac Magnetic Resonance Imaging',
#  'CPET': 'cardiopulmonary exercise test',
#  'GnRH': 'Gonadotropin-releasing hormone',
#  'Ao': 'Aorta',
#  'PCR': 'polymerase chain reaction',
#  'Ceftriaxone': 'ceftroline',
#  'Levofloxacin': 'levofloxacillin',
#  'S1': 'first heart sound',
#  'RSBI': 'Respiratory Sensitivity Bioimpedance',
#  'HES': 'Idiopathic Hypereosinophilia',
#  'IDH': 'Intradiaphragmatic Hypertension',
#  'L-R': 'Left-right',
#  'TOE': 'Transoesophageal Echocardiography',
#  'HDL': 'High-density lipoprotein',
#  'LDL': 'Low Density Lipoprotein',
#  'Hemoglobin': 'Hematoglobin',
#  'MPH': 'Millimeter Per Hour',
#  'U500': 'units',
#  'BID': 'twice a day',
#  'MT': 'Metabolic Treatment',
#  'TBI': 'Total Body Irradiation',
#  'cyt': 'Cytosine Arabinoside',
#  'GVHd': 'Graft-Versus-Host Disease, Dermatological',
#  'CCHF': 'Chronic Heart Failure',
#  'TB': 'Total Bilirubin',
#  'HepB': 'Hepatitis B Virus',
#  'HepE': 'Hepatitis E Virus',
#  'CF-LVAD': 'Continuous Flow Left Ventricular Assist Device',
#  'ML': 'Millilitre',
#  'L/min/m^2': 'Liters per Minute per Square Meter',
#  'μg/kg/minute': 'Micrograms per Kilogram per Minute',
#  'SS': 'Symptomatic Systemic Amyloidosis',
#  'CHDF': 'Continuous Hemodialysis/Filtration',
#  'ST-segment': 'segment of the electrocardiogram tracing',
#  'ICCU': 'intensive care unit',
#  'dox': 'doxorubicin',
#  'cis': 'cisplatin',
#  'CHA2DS2-VASc': 'Chronic Heart Failure Assessment Scheme 2-Disease Score Vascular Age Scoring',
#  'S2': 'Second Heart Sound',
#  'IL': 'Illinois',
#  'Caucasian': 'of European descent',
#  'BM': 'Body Mass Index',
#  'BMI': 'Body Mass Index',
#  'PAD': 'Peripheral Artery Disease',
#  'FIP1L1-PDGFRA': 'Focal Involvement Protein 1-Like 1-Platelet-Derived Growth Factor Receptor Alpha',
#  'SGLT2': 'sodium-glucose cotransporter type 2',
#  'TAH': 'Total Artificial Heart',
#  'RT-qPCR': 'real-time quantitative polymerase chain reaction',
#  'EMB': 'endomyocardial biopsy',
#  'Ct': 'cycle threshold',
#  'Dakota': 'DAKO Corporation',
#  'CS': 'Cardiac Surgery',
#  'OED': 'Oedema',
#  'SI': 'Sinus tachycardia',
#  'L–1': 'per litre per minute',
#  'mmol L–1': 'millimoles per litre',
#  'kg–1 h–1': 'kilograms per hour',
#  'cpap': 'Continuous Positive Airway Pressure',
#  'THF': 'Transthoracic Echocardiography',
#  'CTPA': 'Computed Tomography Pulmonary Angiogram',
#  'COHb': 'Carboxyhemoglobin',
#  'VMI': 'viral myocarditis',
#  'LDLR': 'Low-Density Lipoprotein Receptor',
#  'CHD': 'Congenital Heart Disease',
#  'PIK3CA': 'Phosphatidylinositol 3-kinase Catalytic Subunit Alpha',
#  'c.3140A>G': 'a point mutation at codon 3140 where adenine (A) is replaced by guanine (G)',
#  'H1047R': 'Histidine to Arginine substitution',
#  'mosaicism': 'the presence of two or more populations of cells with different genetic makeup',
#  'natriuretic peptide': 'a hormone produced by the heart that helps regulate blood pressure',
#  'rnapycin': 'rapamycin',
#  'Rapamycin': 'an immunosuppressant medication',
#  'PET': 'Positron emission tomography',
#  'BYL719': 'BRAF inhibitor',
#  'Maquet': 'Getinge Group',
#  'b.p.': 'beats per minute',
#  'HWAD': 'HeartWare Assist Device',
#  'LAA': 'Left Atrial Appendage',
#  'RV EFR': 'Right Ventricular Ejection Fraction',
#  'TE': 'transthoracic echocardiography',
#  'tocolizumab': 'Tocilizumab is an interleukin-6 receptor antagonist used to treat severe cytokine release syndrome associated with COVID-19.',
#  'MCS': 'Mechanical Circulatory Support',
#  'VECMO': 'Venovenous Extracorporeal Membrane Oxygenation',
#  'LVEDC': 'Left Ventricular End-Diastolic Compression',
#  'LLV': 'Left Lower Lobe Vein',
#  'LVNC': 'Left Ventricular Non-Compaction',
#  'IL-6': 'Interleukin-6',
#  'βMPC': 'Bone Marrow Plasma Cell',
#  'L4': 'Fourth Lumbar Vertebrae',
#  'BAD': 'Bortezomib, Doxorubicin Hydrochloride Liposome and Dexamethasone',
#  'PAH': 'Pulmonary Artery Hypertension',
#  'RVC': 'Right Ventricle Cardiac Function Index',
#  'AZA': 'Azathioprine',
#  'NICMP': 'Neuromuscular Chronic Musculoskeletal Pain',
#  'LAP': 'Left Atrial Pressure',
#  'V-wave': 'V wave pressure',
#  'IPG': 'interstitial pulse generator',
#  'Apgar': 'Appearance, Pulse, Grimace, Activity, Respiration',
#  'CGH': 'Chromosomal Genomic Hybridization',
#  'RASA1': 'Ras-related protein 1',
#  'CA-125': 'carcinoma antigen 125',
#  'G4P4': 'Gravida 4 Para 4',
#  'VSR': 'Ventricular Septal Rupture',
#  'GWW': 'glomerular wall tension',
#  'GWI': 'glomerular wall index',
#  'EGPA-CSS': 'Eosinophilic Granulomatosis with Polyangiitis-Churg-Strauss Syndrome',
#  'min': 'minute(s)',
#  'second(s)': '',
#  'WRF': 'Wilkins Rodman Finklestein test',
#  'HMT': 'HeartMate',
#  'TLV': 'Tolvaptan',
#  'CTE': 'Chronic Total Occlusion',
#  'ESSR': 'erythrocyte sedimentation rate',
#  'D-Dimmers': 'D-dimer',
#  'HBD': 'hundred birthdays',
#  'SS-A': 'Systemic Lupus Antigen type A',
#  'SS-B': 'Systemic Lupus Antigen type B',
#  'VA': 'Veterans Affairs',
#  'Impella': 'Implantable Ventricular Assist Device',
#  'PET/CT': 'Positron Emission Tomography-Computed Tomography',
#  'BIVAD': 'BiVentricular Assist Device',
#  'ASA': 'American Society of Anesthesiologists',
#  'Kratom': 'Mitragyna speciosa',
#  'Cephalosporin': 'a class of β-lactam antibiotics',
#  'hs-C': 'High-sensitivity C-reactive protein',
#  'dexa': 'Dexamethasone',
#  'MET': 'Metformin',
#  'IPAH': 'Idiopathic Pulmonary Arterial Hypertension',
#  'PAA': 'Pulmonary Artery Anomaly',
#  'ALP': 'Alkaline Phosphatase',
#  'CAP': 'Community Acquired Pneumonia',
#  'TNF-α': 'tumor necrosis factor-alpha',
#  'CAD': 'Coronary Artery Disease',
#  'TnI': 'troponin I',
#  'Ck': 'Creatine Kinase',
#  'LvdD': 'Left Ventricular End Diastolic Dimension',
#  'CoA': 'coarctation of the aorta',
#  'PDA': 'Patent Ductus Arteriosus',
#  "E/e'": 'peak early diastolic left ventricular filling velocity/peak early diastolic velocity of the mitral annulus',
#  'RR': 'Respiratory Rate',
#  'IVS': 'Intra-Ventricular Shunt',
#  'LVPW': 'Left ventricular posterior wall',
#  'LVOT': 'Left ventricle outflow tract',
#  'CHS': 'Cardiac History Syndrome',
#  'MPAP': 'Mean Pulmonary Artery Pressure',
#  'SO2': '% Oxygen Saturation',
#  'HDI': 'High-Dose Insulin',
#  'PS': 'Pulmonary Stenosis',
#  'PR': 'Pulmonary Regurgitation',
#  'SYNCO': 'syncope',
#  'TROPNIN': 'troponin',
#  'NTPROBNP': 'N-terminal pro b-type natriuretic peptide',
#  'T2DM': 'Type 2 Diabetes Mellitus',
#  'MODS': 'Multiple Organ Dysfunction Syndrome',
#  'SIRS': 'Systemic Inflammatory Response Syndrome',
#  'CK': 'Creatine Kinase',
#  'SX': 'Signs and Symptoms',
#  'EVDG': 'End-stage Vascular Disease',
#  'DVCA': 'Diffuse Vasculature Congestion Abnormality',
#  'Hymenoptera': 'Insect order',
#  'MB': 'Myoglobin',
#  'SAR': 'spontaneous arrest response',
#  'TAVR': 'Transcatheter Aortic Valve Replacement',
#  'tachycardia': 'rapid heartbeat',
#  'de novo': 'newly occurring',
#  'ejection fraction': 'the percentage of blood pumped out by the left ventricle each time it contracts',
#  'subsequent': 'happening after something has already happened',
#  'intravenous': 'given into a vein',
#  'antiarrhythmic': 'used to treat abnormal heart rhythms',
#  'recombinant': 'produced artificially using genetic engineering techniques',
#  'necrosis': 'death of cells or tissues due to injury or disease',
#  'mid-cerebral': 'relating to the middle part of the cerebrum',
#  'lactic acidosis': 'buildup of lactate in the blood which can cause serious complications',
#  'bilateral': 'both sides',
#  'pleural': 'relating to the space between the lungs and chest cavity',
#  'pericardial': 'relating to the sac surrounding the heart',
#  'cardiogenic': 'causing heart problems',
#  'mechanical': 'requiring human intervention',
#  'haemolysis': 'breakdown of red blood cells',
#  'bradycardia': 'slow heart rate',
#  'hyperlipidemia': 'high levels of lipids in the blood',
#  'ISTEMI': 'non-ST-segment elevation myocardial infarction',
#  'marginal': 'branch off from the main artery',
#  'Minnesota': 'state where St. Jude Medical is located',
#  'Thunder Valley': 'not mentioned but could refer to the location of the aortic bifurcation',
#  'ET': 'Echocardiogram',
#  'SARSCoV-2 PCR': 'Severe Acute Respiratory Syndrome Coronavirus 2 Polymerase Chain Reaction',
#  'EGPA': 'Eosinophilic Granulomatosis with Polyangiitis',
#  'ANCA': 'Anti-Neutrophil Cytoplasmic Antibodies',
#  'warfarin': 'a type of vitamin K antagonist used as an anticoagulant',
#  'hct': 'Haematocrit',
#  'mRI': 'Mean Corpuscular Volume',
#  'iNRT': 'International Normalized Ratio',
#  'sCr': 'Serum Creatinine',
#  'alb': 'Albumin',
#  'CIED': 'Conventional Implantable Cardioverter Defibrillator',
#  'VF': 'Ventricular Fibrillation',
#  't.i.d.': 'three times a day',
#  'q.d.': 'once a day',
#  'p.t.': 'postprandially',
#  'SIADH': 'Syndrome Of Inappropriate Antidiuretic Hormone',
#  'end-o-myocardial biopsies': '',
#  ' mmHg': 'millimeters of mercury',
#  'RT-PCR': 'Reverse Transcription Polymerase Chain Reaction',
#  'sARS-CoV-2': 'Severe Acute Respiratory Syndrome Coronavirus 2',
#  'FiO2': 'fraction of inspired oxygen',
#  'MAP': 'Mean Arterial Pressure',
#  'ECC': 'Emergency Cardiovascular Care',
#  'Lung Fields': 'Lungs',
#  'RWMA': 'Regional Wall Motion Abnormality',
#  'NHL': 'Non-Hodgkin Lymphoma',
#  'CHT': 'Chemotherapy',
#  'RT': 'Radiation Therapy',
#  'Mel-Dex': 'Melphalan + Dexamethasone',
#  'Len-Dex': 'Lenalidomide + Dexamethasone',
#  'IE': 'Infective Endocarditis',
#  'GCS': 'Glasgow Coma Scale',
#  'TTR': 'Transthyretin',
#  'JVD': 'Jugular Venous Distension',
#  'ARNI': 'Angiotensin Receptor-Neprilysin Inhibitor',
#  'ACHD': 'Adult Congenital Heart Disease',
#  'SSPE': 'Subacute Bacterial Endocarditis',
#  'PV': 'pressure-volume',
#  'A2': 'anterior leaflet',
#  'HMII': 'HeartMate II',
#  'IDC': 'Idiopathic Dilated Cardiomyopathy',
#  'FISH': 'Fluorescence In Situ Hybridization',
#  'OPD': 'Office of Patient Data',
#  'LVS3': 'Left Ventricular Systolic Dysfunction Grade III',
#  'UM': 'Urothelial Carcinoma',
#  'R&D': 'Research and Development',
#  'EMCS': 'emergency cesarean section',
#  'AICD': 'Automatic Internal Cardioverter Defibrillator',
#  'prostheses': 'artificial devices implanted inside the body to replace damaged organs or parts.',
#  'mAC': 'Monitored Anesthesia Care',
#  'sinus P-wave': 'normal heartbeat pattern',
#  'MAT': 'multifocal atrial tachycardia',
#  'TSAb': 'thyrostimulating antibody',
#  'TRAb': 'thyrotropin receptor antibody',
#  'Ventricular Extrasystoles': 'extra beats originating from the ventricles',
#  'VGM': 'Vein of Galen Malformation',
#  'Lasjuanias': 'Mal de Las Juanas',
#  'Bicêtre': 'Bicetre Score',
#  'FS': 'Fraction Shortening',
#  'NTPBNNBP': 'n terminal prohormone of brain natriuretic peptide',
#  'GRAVIDA': 'pregnancy',
#  'PARA': 'childbirth',
#  'ULTRASONOGRAHY': 'ultrasound imaging',
#  'SUPRATENTORIAL': 'above the tentorium cerebelli',
#  'INFRATENTORIAL': 'below the tentorium cerebelli',
#  'BIPARIETAL DIAMETER': 'the distance between the two sides of the head',
#  'PFOE': 'Patent foramen ovale exclusion',
#  'APE': 'Acute Pulmonary Embolism',
#  'pericardial effusion': 'fluid accumulation between the layers of the pericardium',
#  'hs-cTnI': 'High-Sensitivity Cardiac Troponin I',
#  'CRCP': 'C-Reactive Protein',
#  'TG': 'Transplant Glomerulopathy',
#  'FPMB': 'Fittkau Metallbau GmbH',
#  'HM3': 'LVAD model number',
#  'leucocytosis': 'an increase in white blood cells',
#  'ASAH': 'American Society of Anaesthesiologists',
#  'bid': 'bidirectional',
#  'ABG': 'Arterial Blood Gas',
#  'RVA': 'Not specified',
#  'RVI': 'Not specified',
#  'Impella 5.0': 'Abiomed',
#  'VeNAC': 'Venous Access Catheter',
#  'StJudeMedical': 'St. Jude Medical',
#  'FEV1': 'Forced Expiratory Volume in one second',
#  'AZS': 'Azilsartan',
#  'FUR': 'Furosemide',
#  'VTs': 'Ventricular Tachycardia/Arrhythmias',
#  'CARTO': 'anatomical visualization system',
#  'LOS': 'Low Output Syndrome',
#  'tachypnea': 'rapid breathing',
#  'D-TGA': 'Transposition of the Great Arteries',
#  'SPS': 'Supravalvular Pulmonary Stenosis',
#  'MTX': 'Methotrexate',
#  'NSAID': 'Nonsteroidal Anti-Inflammatory Drug',
#  'COVID': 'Coronavirus Disease',
#  'ER': 'Emergency Room',
#  'ART': 'Antiretroviral Therapy',
#  'Rivaroxaban': 'anticoagulant',
#  'IrMSCS': 'Interagency Registry for Mechanically Assisted Circulatory Support',
#  'ThunderKlyte': '',
#  'ABC': 'Anterior Circulation Blockage',
#  'CBC': 'Complete Blood Count',
#  'DM': 'Diabetes Mellitus',
#  'EGFR': 'Epidermal Growth Factor Receptor',
#  'HbA1C': 'Haemoglobin A1c',
#  'LIPR': 'Left Internal Pulmonary Regurgitation',
#  'NPO': 'Nil Per Os',
#  'TAPVR': 'total anomalous pulmonary venous return',
#  'WPW': 'Wolff-Parkinson-White',
#  'dh': '',
#  'edema': 'swelling caused by excess fluid',
#  'hypohidrosis': 'absence of sweating',
#  'ab': 'Abortion',
#  'TPO': 'Thyroperoxidase',
#  'TRH': 'Thyrotropin-releasing hormone',
#  'ACC': 'American College of Cardiology',
#  'MPGN': 'Membranoproliferative Glomerulonephritis',
#  'RVSP': 'Right Ventricular Systolic Pressure',
#  'EST': 'Exercise Stress Test',
#  'EM': 'Eosinophilic Myocarditis',
#  'CTEP': '',
#  'echocardiography': 'echo',
#  'CD7': 'Cluster of Differentiation 7',
#  'BJ': '',
#  'cycles': '',
#  'cures': '',
#  'mg': 'milligram(s)',
#  'm2': '',
#  'standards': '',
#  'I': '',
#  'II': 'second',
#  'pumps': '',
#  'transplant': '',
#  'VAD': 'Venous Access Device',
#  'A–E': 'Assessment',
#  'C': 'cell',
#  'X': 'X-ray',
#  'CAAE': 'Central Adjudication Agency Evaluation',
#  'LLC': 'Limited Liability Company',
#  'Erythro': 'erythrovirus',
#  'FI02': 'Fraction Inspired Oxygen',
#  'SCT': 'Autologous Stem Cell Transplantation',
#  'P3G3': 'Full-term birth, Parity 3, Gestation age 33',
#  'B': 'Blood type',
#  'exercise tolerance': 'Ability to perform physical activity without fatigue',
#  'C waves': 'Abnormal wave seen in the jugular venous pulse associated with tricuspid stenosis',
#  'diurese': 'To increase urine production through medication',
#  'P1': 'Patient One',
#  'ms': 'milliseconds',
#  'LBBAP': 'Left Bundle Branch Activation Prevention',
#  'CR': 'Controlled Release',
#  'IIaR': 'Angiotensin II Receptor Antagonist',
#  'HLH-2004': 'Haemophagocytic Lymphohistiocytosis - 2004',
#  'D-HEMO': '',
#  'H-Score': '',
#  'ST-seq': 'Short-term segment',
#  'EuroSCORE': 'European System for Cardiac Operative Risk Evaluation',
#  'Spiromolactone': 'spironolactone',
#  'IT': 'Immunotherapy',
#  'p.o.': 'per os',
#  'EGC': 'Electrocardiogram',
#  'muL': 'micro liters',
#  'μg/L': 'micrograms per liter',
#  'UML': 'units of measurement length',
#  'TDI': 'tissue Doppler imaging',
#  'BIPAP': 'Bilevel Positive Airway Pressure',
#  'SOB': 'Shortness of Breath',
#  'PaO2': 'Partial Pressure of Oxygen in Arterial Blood',
#  'SaO2': 'SpO2',
#  'IDA': 'Iron Deficiency Anemia',
#  'ndCKD': 'Chronic Kidney Disease',
#  'CIC': 'Comorbid Conditions',
#  'TTTE': 'Transthoracic Two-Dimensional Echocardiogram',
#  'TN': 'Troponin',
#  'PPIs': 'Proton Pump Inhibitors',
#  'TmP/GFR': 'Total Mineralocorticoid Reabsorbability at Glomerular Filtration Rate',
#  'PAV': 'Pacing Activation Voltage',
#  'SAV': 'Sensing Activation Voltage',
#  'VV': 'Ventrical-Ventrical Interval',
#  'BiV': 'Biventricular Paced',
#  'ABP': 'arterial blood pressure',
#  'BAG3': 'BCL2-associated athanogene 3',
#  'APHCM': 'Apical Hypertrophic Cardiomyopathy',
#  'MYH7': 'Myosin Heavy Chain 7 Gene',
#  'GATA6': 'GATA Binding Protein 6 Gene',
#  'TOF': 'Tetralogy of Fallot',
#  'RVOTS': 'Right Ventricular Outflow Obstruction Syndrome',
#  'SHF': 'Subaortic Hypertrophic Functionality',
#  'PTB': 'Pulmonary Tuberculosis',
#  'ALL': 'Acute Lymphoblastic Leukemia',
#  'RSA': 'Right Subclavian Artery',
#  'hs-TnI': 'High-sensitivity Troponin I',
#  'U.S.': 'United States',
#  'ALKPHOS': 'Alkaline Phosphatase',
#  'GGT': 'Gamma Glutamyl Transpeptidase',
#  'KETOLACTONE': 'Ketone Body Test Result',
#  'AAS': 'Anabolic Androgen Steroid',
#  'LVDS': 'Left Ventricular Systolic Thickness',
#  'NCT': 'National Clinical Trials',
#  'K': 'thousand',
#  'SBRT': 'Stereotactic Body Radiation Therapy',
#  'TPA': '',
#  'CPRP': 'C-Reactive Protein',
#  'T790': 'Threonine 790',
#  'ST-T': 'ST Segment - T Wave',
#  'AMPLATZER': 'Vascular Plug II',
#  'PPSV23': 'Pneumovax',
#  'NP': 'Merck & Co., Inc.',
#  'NJ': 'Kenilworth',
#  'HCO3−': 'Bicarbonate ion',
#  'biventricular': 'relating to two chambers',
#  'ST-ELEVATION MI': 'Myocardial Infarction',
#  'asthma': 'chronic lung disease characterized by wheezing, coughing, and difficulty breathing',
#  'inhaler': 'device used to deliver medication directly into the lungs through inhalation',
#  'stridor': 'abnormal high-pitched sound heard during breathing',
#  'laryngoscopy': 'examination using a mirror to view the larynx (voice box)',
#  'bronchoscopy': 'examination using a flexible tube with a camera to visualize the inside of the airways',
#  'PAP': 'pulmonary artery pressure',
#  'PAWP': 'pulmonary wedge pressure',
#  'ASTHMA': 'a chronic inflammatory disease of the airways characterized by recurring episodes of reversible airflow obstruction',
#  ...}

# %%
ner_results_1 = pipe(example1)
ner_results_2 = pipe(example2)

proc_results_1 = process_ner_results(ner_results_1)
proc_results_2 = process_ner_results(ner_results_2)

results_1 = assemble_ner_output_flat(proc_results_1)
results_2 = assemble_ner_output_flat(proc_results_2)

# %%
results_2
# Out:
# [{'label': 'DISEASE',
#   'text': 'Complete occlusion of proximal',
#   'start': 256,
#   'end': 286,
#   'score': 0.7898994258471898},
#  {'label': 'DISEASE',
#   'text': 'anterior',
#   'start': 292,
#   'end': 300,
#   'score': 0.5233062505722046},
#  {'label': 'DISEASE',
#   'text': 'Intramyocardial hematoma',
#   'start': 321,
#   'end': 345,
#   'score': 0.9866578802466393},
#  {'label': 'DISEASE',
#   'text': 'IMH',
#   'start': 347,
#   'end': 350,
#   'score': 0.4332329034805298},
#  {'label': 'DISEASE',
#   'text': 'Congestive heart failure',
#   'start': 354,
#   'end': 378,
#   'score': 0.9912551283836365},
#  {'label': 'DISEASE',
#   'text': 'Ventricular tachycardia',
#   'start': 381,
#   'end': 404,
#   'score': 0.9940839409828186},
#  {'label': 'PROCEDURE',
#   'text': 'primary percutaneous coronary intervention',
#   'start': 443,
#   'end': 485,
#   'score': 0.5631036758422852},
#  {'label': 'PROCEDURE',
#   'text': 'pPCI',
#   'start': 487,
#   'end': 491,
#   'score': 0.5993131399154663},
#  {'label': 'DISEASE',
#   'text': 'completely occluded proximal left anterior descending artery',
#   'start': 499,
#   'end': 559,
#   'score': 0.867210304737091},
#  {'label': 'MEDICATION',
#   'text': 'diltiazem',
#   'start': 667,
#   'end': 676,
#   'score': 0.9900557994842529},
#  {'label': 'MEDICATION',
#   'text': 'nicorandil',
#   'start': 681,
#   'end': 691,
#   'score': 0.9833632558584213},
#  {'label': 'PROCEDURE',
#   'text': 'echocardiogram',
#   'start': 735,
#   'end': 749,
#   'score': 0.9657158970832824},
#  {'label': 'DISEASE',
#   'text': 'intramyocardial hematoma',
#   'start': 889,
#   'end': 913,
#   'score': 0.9838776811957359},
#  {'label': 'DISEASE',
#   'text': 'IMH',
#   'start': 915,
#   'end': 918,
#   'score': 0.9456562399864197},
#  {'label': 'DISEASE',
#   'text': 'congestive heart failure',
#   'start': 1098,
#   'end': 1122,
#   'score': 0.991908609867096},
#  {'label': 'DISEASE',
#   'text': 'IMH',
#   'start': 1177,
#   'end': 1180,
#   'score': 0.833314836025238},
#  {'label': 'DISEASE',
#   'text': 'ventricular tachycardia',
#   'start': 1373,
#   'end': 1396,
#   'score': 0.9883089959621429},
#  {'label': 'SYMPTOM',
#   'text': 'EF',
#   'start': 1423,
#   'end': 1425,
#   'score': 0.502463161945343},
#  {'label': 'DISEASE',
#   'text': 'apical aneurysm',
#   'start': 1464,
#   'end': 1479,
#   'score': 0.9610544939835867},
#  {'label': 'DISEASE',
#   'text': 'heart failure',
#   'start': 1672,
#   'end': 1685,
#   'score': 0.978159487247467}]

# %%
import pandas as pd
df_res_1 = pd.DataFrame(results_1)[["label", "text"]].drop_duplicates()
df_res_1["in_cc"] = 1
df_res_1
# Out:
#          label                                               text  in_cc
# 0    PROCEDURE         primary percutaneous coronary intervention      1
# 1    PROCEDURE                                               pPCI      1
# 2      DISEASE  occluded proximal left anterior descending artery      1
# 3   MEDICATION                                          diltiazem      1
# 4   MEDICATION                                         nicorandil      1
# 5    PROCEDURE                                     echocardiogram      1
# 6      DISEASE                          intramyocardial haematoma      1
# 7      DISEASE                                                IMH      1
# 8      DISEASE                           congestive heart failure      1
# 9      DISEASE                                                  H      1
# 10     DISEASE                            ventricular tachycardia      1
# 11     DISEASE                                    apical aneurysm      1

# %%
df_res_2 = pd.DataFrame(results_2)[["label", "text"]].drop_duplicates()
df_res_2["in_ds"] = 1
df_res_2
# Out:
#          label                                               text  in_ds
# 0      DISEASE                     Complete occlusion of proximal      1
# 1      DISEASE                                           anterior      1
# 2      DISEASE                           Intramyocardial hematoma      1
# 3      DISEASE                                                IMH      1
# 4      DISEASE                           Congestive heart failure      1
# 5      DISEASE                            Ventricular tachycardia      1
# 6    PROCEDURE         primary percutaneous coronary intervention      1
# 7    PROCEDURE                                               pPCI      1
# 8      DISEASE  completely occluded proximal left anterior des...      1
# 9   MEDICATION                                          diltiazem      1
# 10  MEDICATION                                         nicorandil      1
# 11   PROCEDURE                                     echocardiogram      1
# 12     DISEASE                           intramyocardial hematoma      1
# 14     DISEASE                           congestive heart failure      1
# 16     DISEASE                            ventricular tachycardia      1
# 17     SYMPTOM                                                 EF      1
# 18     DISEASE                                    apical aneurysm      1
# 19     DISEASE                                      heart failure      1

# %%
df_tot = df_res_2.merge(df_res_1, on=["label", "text"], how="outer").fillna(0)
df_tot
# Out:
#          label                                               text  in_ds  \
# 0      DISEASE                     Complete occlusion of proximal    1.0
# 1      DISEASE                           Congestive heart failure    1.0
# 2      DISEASE                                                  H    0.0
# 3      DISEASE                                                IMH    1.0
# 4      DISEASE                           Intramyocardial hematoma    1.0
# 5      DISEASE                            Ventricular tachycardia    1.0
# 6      DISEASE                                           anterior    1.0
# 7      DISEASE                                    apical aneurysm    1.0
# 8      DISEASE  completely occluded proximal left anterior des...    1.0
# 9      DISEASE                           congestive heart failure    1.0
# 10     DISEASE                                      heart failure    1.0
# 11     DISEASE                          intramyocardial haematoma    0.0
# 12     DISEASE                           intramyocardial hematoma    1.0
# 13     DISEASE  occluded proximal left anterior descending artery    0.0
# 14     DISEASE                            ventricular tachycardia    1.0
# 15  MEDICATION                                          diltiazem    1.0
# 16  MEDICATION                                         nicorandil    1.0
# 17   PROCEDURE                                     echocardiogram    1.0
# 18   PROCEDURE                                               pPCI    1.0
# 19   PROCEDURE         primary percutaneous coronary intervention    1.0
# 20     SYMPTOM                                                 EF    1.0
#
#     in_cc
# 0     0.0
# 1     0.0
# 2     1.0
# 3     1.0
# 4     0.0
# 5     0.0
# 6     0.0
# 7     1.0
# 8     0.0
# 9     1.0
# 10    0.0
# 11    1.0
# 12    0.0
# 13    1.0
# 14    1.0
# 15    1.0
# 16    1.0
# 17    1.0
# 18    1.0
# 19    1.0
# 20    0.0

# %%
df_tot[df_tot["in_cc"] + df_tot["in_ds"] <= 1]
# Out:
#       label                                               text  in_ds  in_cc
# 0   DISEASE                     Complete occlusion of proximal    1.0    0.0
# 1   DISEASE                           Congestive heart failure    1.0    0.0
# 2   DISEASE                                                  H    0.0    1.0
# 4   DISEASE                           Intramyocardial hematoma    1.0    0.0
# 5   DISEASE                            Ventricular tachycardia    1.0    0.0
# 6   DISEASE                                           anterior    1.0    0.0
# 8   DISEASE  completely occluded proximal left anterior des...    1.0    0.0
# 10  DISEASE                                      heart failure    1.0    0.0
# 11  DISEASE                          intramyocardial haematoma    0.0    1.0
# 12  DISEASE                           intramyocardial hematoma    1.0    0.0
# 13  DISEASE  occluded proximal left anterior descending artery    0.0    1.0
# 20  SYMPTOM                                                 EF    1.0    0.0

# %%
import re
df_proc_gaz = pd.read_csv("data/4_gazetteers/en/english_procedures_gazetteer.tsv", sep="\t")
df_proc_gaz[df_proc_gaz["term"].apply(lambda x: re.match("^[A-Z]{1,5}\s\(.{3,}\).+$", x) is not None)]
# Out:
#               code language  \
# 2789    1335957003       en
# 2815     698451006       en
# 2817    1230374008       en
# 2818    1230375009       en
# 2829     233169004       en
# ...            ...      ...
# 225409    15218003       en
# 225410   237371007       en
# 225411  1231286004       en
# 227095   833324006       en
# 227348   840286006       en
#
#                                                      term semantic_tag  \
# 2789                AAV (Adeno-associated virus) antibody    substance
# 2815    ABPI (Ankle brachial pressure index) test decl...    situation
# 2817         ABR (auditory brainstem response) with click    procedure
# 2818          ABR (auditory brainstem response) with tone    procedure
# 2829      ACD (automatic cardiac defibrillator) procedure    procedure
# ...                                                   ...          ...
# 225409  WISC (Wechsler Intelligence Scale for Children...    procedure
# 225410         WLE (wide local excision) of breast lesion    procedure
# 225411  WLE (wide local excision) of lesion of breast ...    procedure
# 227095    YAG (yttrium aluminum garnet) laser vitreolysis    procedure
# 227348                       ZTE (zero echo time) imaging    procedure
#
#                                             parents  mainterm
# 2789                                     [77767001]         0
# 2815                                   [1296859006]         0
# 2817                                    [252616000]         0
# 2818                                    [252616000]         0
# 2829                                    [425934009]         0
# ...                                             ...       ...
# 225409                                   [72657008]         0
# 225410            [392023007, 787439005, 773170003]         0
# 225411                       [237371007, 710955000]         0
# 227095  [17348004, 122459003, 608849003, 118903006]         0
# 227348                                  [113091000]         0
#
# [427 rows x 6 columns]

# %%
df_dis_gaz = pd.read_csv("data/4_gazetteers/en/english_diseases_gazetteer.tsv", sep="\t")
df_dis_gaz[df_dis_gaz["term"].apply(lambda x: re.match("^[A-Z]{1,5}\s\(.{3,}\).+$", x) is not None)]
# Out:
#               code language  \
# 570      246991003       en
# 582      720979002       en
# 583      720979002       en
# 595     1345055005       en
# 597     1306301007       en
# ...            ...      ...
# 186711   726572009       en
# 186727  1186725001       en
# 186728  1186725001       en
# 186731   733909005       en
# 188287   770558006       en
#
#                                                      term  \
# 570                            AC (anterior chamber) deep
# 582     ACD (alopecia, contracture, dwarfism) mental r...
# 583        ACD (alopecia, contracture, dwarfism) syndrome
# 595               ACF (asymmetric crying facies) syndrome
# 597              ACG (angle closure glaucoma) of left eye
# ...                                                   ...
# 186711                        WBC (white blood cell) cast
# 186727  WILD (warts, immunodeficiency, lymphedema, ano...
# 186728  WILD (warts, immunodeficiency, lymphoedema, an...
# 186731           WNT (Wingless) activated medulloblastoma
# 188287  ZASP (Z-band alternatively spliced PDZ motif p...
#
#                    semantic_tag  \
# 570                     finding
# 582                    disorder
# 583                    disorder
# 595                    disorder
# 597                    disorder
# ...                         ...
# 186711  morphologic abnormality
# 186727                 disorder
# 186728                 disorder
# 186731  morphologic abnormality
# 188287                 disorder
#
#                                                   parents  mainterm
# 570                                           [301933003]         0
# 582     [8654005, 23359005, 85995004, 363185004, 11035...         0
# 583     [8654005, 23359005, 85995004, 363185004, 11035...         0
# 595     [11164009, 205530002, 363070008, 363212003, 65...         0
# 597                        [12239461000119106, 392291006]         0
# ...                                                   ...       ...
# 186711                             [725685009, 734910007]         0
# 186727  [254199006, 58606001, 699346009, 128937004, 29...         0
# 186728  [254199006, 58606001, 699346009, 128937004, 29...         0
# 186731                                       [1156923005]         0
# 188287                   [11164009, 699269005, 363212003]         0
#
# [468 rows x 6 columns]

# %%
df_sym_gaz = pd.read_csv("data/4_gazetteers/en/english_symptoms_gazetteer.tsv", sep="\t")
df_sym_gaz[df_sym_gaz["term"].apply(lambda x: re.match("^[A-Z]{1,5}\s\(.{3,}\).+$", x) is not None)]
# Out:
#               code language  \
# 717      246991003       en
# 728      720979002       en
# 729      720979002       en
# 742     1345055005       en
# 744     1306301007       en
# ...            ...      ...
# 224756   726572009       en
# 224793  1186725001       en
# 224794  1186725001       en
# 224797   733909005       en
# 226897   770558006       en
#
#                                                      term  \
# 717                            AC (anterior chamber) deep
# 728     ACD (alopecia, contracture, dwarfism) mental r...
# 729        ACD (alopecia, contracture, dwarfism) syndrome
# 742               ACF (asymmetric crying facies) syndrome
# 744              ACG (angle closure glaucoma) of left eye
# ...                                                   ...
# 224756                        WBC (white blood cell) cast
# 224793  WILD (warts, immunodeficiency, lymphedema, ano...
# 224794  WILD (warts, immunodeficiency, lymphoedema, an...
# 224797           WNT (Wingless) activated medulloblastoma
# 226897  ZASP (Z-band alternatively spliced PDZ motif p...
#
#                    semantic_tag  \
# 717                     finding
# 728                    disorder
# 729                    disorder
# 742                    disorder
# 744                    disorder
# ...                         ...
# 224756  morphologic abnormality
# 224793                 disorder
# 224794                 disorder
# 224797  morphologic abnormality
# 226897                 disorder
#
#                                                   parents  mainterm
# 717                                           [301933003]         0
# 728     [8654005, 23359005, 85995004, 363185004, 11035...         0
# 729     [8654005, 23359005, 85995004, 363185004, 11035...         0
# 742     [11164009, 205530002, 363070008, 363212003, 65...         0
# 744                        [12239461000119106, 392291006]         0
# ...                                                   ...       ...
# 224756                             [725685009, 734910007]         0
# 224793  [254199006, 58606001, 699346009, 128937004, 29...         0
# 224794  [254199006, 58606001, 699346009, 128937004, 29...         0
# 224797                                       [1156923005]         0
# 226897                   [11164009, 699269005, 363212003]         0
#
# [553 rows x 6 columns]

# %%
dis_terms = df_dis_gaz["term"].unique()
df_sym_gaz["term"].isin(dis_terms).sum()
# Out:
# 182741

# %%
from sentence_transformers import SentenceTransformer
model_st = SentenceTransformer("/gpfs/projects/bsc14/abecerr1/hub/models--cambridgeltl--SapBERT-from-PubMedBERT-fulltext-mean-token/snapshots/9f95c2e962719c70f25bf7a1f33bd8d9e9448750", device="cuda:1")
# faiss_index = FaissIndex(model=model_st, gazetteer_path=path_to_gaz, random_seed=SEED, training_data_path=TRAINING_DATA)
# Out:
# No sentence-transformers model found with name /gpfs/projects/bsc14/abecerr1/hub/models--cambridgeltl--SapBERT-from-PubMedBERT-fulltext-mean-token/snapshots/9f95c2e962719c70f25bf7a1f33bd8d9e9448750. Creating a new one with mean pooling.

# %%
from src.search_index import FaissIndex
faiss_index = FaissIndex(model=model_st, gazetteer_path="data/4_gazetteers/en/english_procedures_gazetteer.tsv", random_seed=0)

# %%
faiss_index.generate_search_index()
# Out:
# Batches:   0%|          | 0/7141 [00:00<?, ?it/s]

# %%
query_embs_1 = model_st.encode(df_res_1["text"].tolist())
query_embs_2 = model_st.encode(df_res_2["text"].tolist())

# %%
_, I1 = faiss_index.search(query_embs_1, k=10)
_, I2 = faiss_index.search(query_embs_2, k=10)

# %%
ls_codes_1 = [[faiss_index.get_code_by_index(i) for i in row] for row in I1]
ls_terms_1 = [[faiss_index.get_term_by_index(i) for i in row] for row in I1]

df_res_1["faiss_code"] = ls_codes_1
df_res_1["faiss_term"] = ls_terms_1

ls_codes_2 = [[faiss_index.get_code_by_index(i) for i in row] for row in I2]
ls_terms_2 = [[faiss_index.get_term_by_index(i) for i in row] for row in I2]

df_res_2["faiss_code"] = ls_codes_2
df_res_2["faiss_term"] = ls_terms_2

# %%
df_res_1.iloc[7]["faiss_term"]
# Out:
# ['History of idiopathic intracranial hypertension',
#  'Hypothalamic inhibiting factor',
#  'ICSH',
#  'IM - Intramuscular induction',
#  'Intermittent haemofiltration',
#  'IM - Intramuscular injection',
#  'IMI - Intramuscular injection',
#  'Intermittent hemofiltration',
#  'Imidazole',
#  'Implantable infusion pump']

# %%
df_tot = df_res_1.merge(df_res_2, on=["label", "text"], how="outer",suffixes=("_cc", "_ds")).fillna(0)
df_tot
# Out:
#          label                                               text  in_cc  \
# 0      DISEASE                     Complete occlusion of proximal    0.0
# 1      DISEASE                           Congestive heart failure    0.0
# 2      DISEASE                                                  H    1.0
# 3      DISEASE                                                IMH    1.0
# 4      DISEASE                           Intramyocardial hematoma    0.0
# 5      DISEASE                            Ventricular tachycardia    0.0
# 6      DISEASE                                           anterior    0.0
# 7      DISEASE                                    apical aneurysm    1.0
# 8      DISEASE  completely occluded proximal left anterior des...    0.0
# 9      DISEASE                           congestive heart failure    1.0
# 10     DISEASE                                      heart failure    0.0
# 11     DISEASE                          intramyocardial haematoma    1.0
# 12     DISEASE                           intramyocardial hematoma    0.0
# 13     DISEASE  occluded proximal left anterior descending artery    1.0
# 14     DISEASE                            ventricular tachycardia    1.0
# 15  MEDICATION                                          diltiazem    1.0
# 16  MEDICATION                                         nicorandil    1.0
# 17   PROCEDURE                                     echocardiogram    1.0
# 18   PROCEDURE                                               pPCI    1.0
# 19   PROCEDURE         primary percutaneous coronary intervention    1.0
# 20     SYMPTOM                                                 EF    0.0
#
#                                         faiss_code_cc  \
# 0                                                   0
# 1                                                   0
# 2   [2141009, 2141009, 115744003, 91137000, 700500...
# 3   [16235071000119108, 44681007, 64182005, 241690...
# 4                                                   0
# 5                                                   0
# 6                                                   0
# 7   [233087003, 80377005, 80377005, 10615008, 4902...
# 8                                                   0
# 9   [433305001, 161505003, 395105005, 134378009, 3...
# 10                                                  0
# 11  [36843004, 149213005, 36843004, 281753007, 226...
# 12                                                  0
# 13  [86642005, 1217158001, 1217158001, 1217158001,...
# 14  [870252007, 429046004, 1098861000119103, 24315...
# 15  [372793000, 59941008, 59941008, 105163002, 122...
# 16  [395809002, 319304004, 319304004, 387457003, 3...
# 17  [40701008, 40701008, 40701008, 40701008, 43323...
# 18  [415070008, 415070008, 405741001, 103810006, 1...
# 19  [415070008, 415070008, 405741001, 414089002, 8...
# 20                                                  0
#
#                                         faiss_term_cc  in_ds  \
# 0                                                   0    1.0
# 1                                                   0    1.0
# 2   [Hydrogen, H - Hydrogen, H antigen, Heavy hydr...    0.0
# 3   [History of idiopathic intracranial hypertensi...    1.0
# 4                                                   0    1.0
# 5                                                   0    1.0
# 6                                                   0    1.0
# 7   [Left ventricular aneurysm operation, Aneurysm...    1.0
# 8                                                   0    1.0
# 9   [Family history of congestive heart failure, H...    1.0
# 10                                                  0    1.0
# 11  [Injection of heart, Internal cardiac massage,...    0.0
# 12                                                  0    1.0
# 13  [Anastomosis of descending aorta to left pulmo...    0.0
# 14  [Ventricular tachycardia ablation, History of ...    1.0
# 15  [Diltiazem, Product containing diltiazem, Dilt...    1.0
# 16  [Nicorandil, Product containing nicorandil, Ni...    1.0
# 17  [Echocardiogram, Echocardiography, Echocardiog...    1.0
# 18  [Percutaneous coronary intervention, PCI - Per...    1.0
# 19  [Percutaneous coronary intervention, PCI - Per...    1.0
# 20                                                  0    1.0
#
#                                         faiss_code_ds  \
# 0   [243208002, 410488006, 278683009, 243209005, 4...
# 1   [433305001, 161505003, 395105005, 134378009, 3...
# 2                                                   0
# 3   [16235071000119108, 44681007, 64182005, 241690...
# 4   [36843004, 149213005, 281753007, 36843004, 830...
# 5   [870252007, 429046004, 1098861000119103, 24315...
# 6   [257481004, 39845007, 264781008, 224748006, 17...
# 7   [233087003, 80377005, 80377005, 10615008, 4902...
# 8   [1217158001, 86642005, 175212004, 1217158001, ...
# 9   [433305001, 161505003, 395105005, 134378009, 3...
# 10  [161505003, 395105005, 308118002, 394887005, 3...
# 11                                                  0
# 12  [36843004, 149213005, 281753007, 36843004, 830...
# 13                                                  0
# 14  [870252007, 429046004, 1098861000119103, 24315...
# 15  [372793000, 59941008, 59941008, 105163002, 122...
# 16  [395809002, 319304004, 319304004, 387457003, 3...
# 17  [40701008, 40701008, 40701008, 40701008, 43323...
# 18  [415070008, 415070008, 405741001, 103810006, 1...
# 19  [415070008, 415070008, 405741001, 414089002, 8...
# 20  [250908004, 409500003, 460616007, 250908004, 4...
#
#                                         faiss_term_ds
# 0   [Orthoptic full time occlusion treatment - tot...
# 1   [Family history of congestive heart failure, H...
# 2                                                   0
# 3   [History of idiopathic intracranial hypertensi...
# 4   [Injection of heart, Internal cardiac massage,...
# 5   [Ventricular tachycardia ablation, History of ...
# 6   [Anterior lead, Anterior repair, AB, Front doo...
# 7   [Left ventricular aneurysm operation, Aneurysm...
# 8   [Anastomosis of LIMA (left internal mammary ar...
# 9   [Family history of congestive heart failure, H...
# 10  [History of heart failure, Heart failure confi...
# 11                                                  0
# 12  [Injection of heart, Internal cardiac massage,...
# 13                                                  0
# 14  [Ventricular tachycardia ablation, History of ...
# 15  [Diltiazem, Product containing diltiazem, Dilt...
# 16  [Nicorandil, Product containing nicorandil, Ni...
# 17  [Echocardiogram, Echocardiography, Echocardiog...
# 18  [Percutaneous coronary intervention, PCI - Per...
# 19  [Percutaneous coronary intervention, PCI - Per...
# 20  [Left ventricular ejection fraction, EF-edema ...

# %%
df_res_1["faiss_code"] = ls_codes
df_res_1["faiss_term"] = ls_terms

# %%
df_res_1
# Out:
#          label                                               text  in_cc  \
# 0    PROCEDURE         primary percutaneous coronary intervention      1
# 1    PROCEDURE                                               pPCI      1
# 2      DISEASE  occluded proximal left anterior descending artery      1
# 3   MEDICATION                                          diltiazem      1
# 4   MEDICATION                                         nicorandil      1
# 5    PROCEDURE                                     echocardiogram      1
# 6      DISEASE                          intramyocardial haematoma      1
# 7      DISEASE                                                IMH      1
# 8      DISEASE                           congestive heart failure      1
# 9      DISEASE                                                  H      1
# 10     DISEASE                            ventricular tachycardia      1
# 11     DISEASE                                    apical aneurysm      1
#
#                                            faiss_code  \
# 0   [415070008, 415070008, 405741001, 414089002, 8...
# 1   [415070008, 415070008, 405741001, 103810006, 1...
# 2   [86642005, 1217158001, 1217158001, 1217158001,...
# 3   [372793000, 59941008, 59941008, 105163002, 122...
# 4   [395809002, 319304004, 319304004, 387457003, 3...
# 5   [40701008, 40701008, 40701008, 40701008, 43323...
# 6   [36843004, 149213005, 36843004, 281753007, 226...
# 7   [16235071000119108, 44681007, 64182005, 241690...
# 8   [433305001, 161505003, 395105005, 134378009, 3...
# 9   [2141009, 2141009, 115744003, 91137000, 700500...
# 10  [870252007, 429046004, 1098861000119103, 24315...
# 11  [233087003, 80377005, 80377005, 10615008, 4902...
#
#                                            faiss_term
# 0   [Percutaneous coronary intervention, PCI - Per...
# 1   [Percutaneous coronary intervention, PCI - Per...
# 2   [Anastomosis of descending aorta to left pulmo...
# 3   [Diltiazem, Product containing diltiazem, Dilt...
# 4   [Nicorandil, Product containing nicorandil, Ni...
# 5   [Echocardiogram, Echocardiography, Echocardiog...
# 6   [Injection of heart, Internal cardiac massage,...
# 7   [History of idiopathic intracranial hypertensi...
# 8   [Family history of congestive heart failure, H...
# 9   [Hydrogen, H - Hydrogen, H antigen, Heavy hydr...
# 10  [Ventricular tachycardia ablation, History of ...
# 11  [Left ventricular aneurysm operation, Aneurysm...

# %%
df_res_1.merge(df_proc_gaz, left_on=["text"], right_on=["term"], how="left")
# Out:
#          label                                               text  in_cc  \
# 0    PROCEDURE         primary percutaneous coronary intervention      1
# 1    PROCEDURE                                               pPCI      1
# 2      DISEASE  occluded proximal left anterior descending artery      1
# 3   MEDICATION                                          diltiazem      1
# 4   MEDICATION                                         nicorandil      1
# 5    PROCEDURE                                     echocardiogram      1
# 6      DISEASE                          intramyocardial haematoma      1
# 7      DISEASE                                                IMH      1
# 8      DISEASE                           congestive heart failure      1
# 9      DISEASE                                                  H      1
# 10     DISEASE                            ventricular tachycardia      1
# 11     DISEASE                                    apical aneurysm      1
#
#     code language term semantic_tag parents  mainterm
# 0    NaN      NaN  NaN          NaN     NaN       NaN
# 1    NaN      NaN  NaN          NaN     NaN       NaN
# 2    NaN      NaN  NaN          NaN     NaN       NaN
# 3    NaN      NaN  NaN          NaN     NaN       NaN
# 4    NaN      NaN  NaN          NaN     NaN       NaN
# 5    NaN      NaN  NaN          NaN     NaN       NaN
# 6    NaN      NaN  NaN          NaN     NaN       NaN
# 7    NaN      NaN  NaN          NaN     NaN       NaN
# 8    NaN      NaN  NaN          NaN     NaN       NaN
# 9    NaN      NaN  NaN          NaN     NaN       NaN
# 10   NaN      NaN  NaN          NaN     NaN       NaN
# 11   NaN      NaN  NaN          NaN     NaN       NaN

# %%
import numpy as np
import torch
from tqdm.auto import tqdm
from transformers import AutoTokenizer, AutoModel  


# replace with your own list of entity names
all_names = ["covid-19", "Coronavirus infection", "high fever", "Tumor of posterior wall of oropharynx"] 

def encode_names(names, device="cuda:0"):
    """
    Encode a list of names using the tokenizer.
    """
    
    tokenizer = AutoTokenizer.from_pretrained("cambridgeltl/SapBERT-from-PubMedBERT-fulltext")  
    model = AutoModel.from_pretrained("cambridgeltl/SapBERT-from-PubMedBERT-fulltext").to(device)
    
    encodings = tokenizer.batch_encode_plus(names, 
                                            padding="max_length", 
                                            max_length=25, 
                                            truncation=True,
                                            return_tensors="pt")
    
    
    # return encodings["input_ids"]


    matrix = model(encodings["input_ids"].to(device), 
            attention_mask=encodings["attention_mask"].to(device))    
    
    
    return matrix[0][:, 0, :].cpu().detach().numpy()
# all_embs = np.concatenate(all_embs, axis=0)
# all_embs

def encode_batch(batch, device="cuda:0"):
    """
    Encode a batch of names using the tokenizer.
    """
    
    tokenizer = AutoTokenizer.from_pretrained("cambridgeltl/SapBERT-from-PubMedBERT-fulltext")  
    model = AutoModel.from_pretrained("cambridgeltl/SapBERT-from-PubMedBERT-fulltext").to(device)
    
    encodings = tokenizer.batch_encode_plus(batch, 
                                            padding="max_length", 
                                            max_length=25, 
                                            truncation=True,
                                            return_tensors="pt")
    
    
    # return encodings["input_ids"]


    matrix = model(encodings["input_ids"].to(device), 
            attention_mask=encodings["attention_mask"].to(device))    
    
    
    return matrix[0][:, 0, :].cpu().detach().numpy()

# %%
from datasets import Dataset
ds = Dataset.from_pandas(df_proc_gaz)

# %%
ds = ds.map(lambda x: {"embeddings": encode_batch(x["term"])}, batched=True, batch_size=1024)
# Out:
# Map:   0%|          | 0/228500 [00:00<?, ? examples/s]

# %%
emb = torch.tensor(ds["embeddings"])
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pandas as pd
import os
import en_ner_bc5cdr_md
from spacy.language import Language
from scispacy.linking import EntityLinker
from tqdm import tqdm
tqdm.pandas()

import sys
# sys.path.append(os.path.abspath(os.path.join(os.path.dirname(__file__), os.path.pardir)))
# sys.path.append("../src")
# print(os.getcwd())

from src.data import files_to_df
from src.scispacy_ie import entity_linker


# print("There are {} original and {} generated samples".format(len(df_orig), len(df_gen)))

nlp = en_ner_bc5cdr_md.load()

try:    # Register the EntityLinker component
    @Language.factory("umls_linker")
    def create_umls_linker(nlp, name):
        return EntityLinker(k=10, max_entities_per_mention=5, name="umls")
    nlp.add_pipe("umls_linker")
    
except ValueError:
    print("Entity linker already exists")
    
# df_ents_orig = df_orig.set_index("filenameid")["text"].swifter.apply(lambda x: entity_linker(nlp, x)).explode().apply(pd.Series)
# df_ents_orig.columns = ["span", "mention_class", "code", "term"]
# df_ents_orig.reset_index(inplace=True)
# df_ents_orig.to_csv(os.path.join(output_path_orig, "ents_orig_scispacy.csv"), index=False)


# df_ents_gen = df_gen.set_index("filenameid")["text"].swifter.apply(lambda x: entity_linker(nlp, x)).explode().apply(pd.Series)
# Out:
# /home/bsc/bsc830651/.local/lib/python3.11/site-packages/spacy/language.py:2195: FutureWarning: Possible set union at position 6328
#   deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(  # type: ignore[union-attr]
# /gpfs/projects/bsc14/scratch/.conda/msds/lib/python3.11/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator TfidfTransformer from version 1.1.2 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /gpfs/projects/bsc14/scratch/.conda/msds/lib/python3.11/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator TfidfVectorizer from version 1.1.2 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
def entity_linker(nlp, text, linker_name="umls_linker"):
    doc = nlp(text)
    linker = nlp.get_pipe(linker_name)
    return [(ent.text, 
             ent.label_, 
             [x[0] for x in ent._.kb_ents] if ent._.kb_ents != [] else None, 
             linker.kb.cui_to_entity[ent._.kb_ents[0][0]].canonical_name\
        if ent._.kb_ents != [] else None) for ent in doc.ents]

# %%
pd.DataFrame(entity_linker(nlp, example1))
# Out:
#                            0         1                     2  \
# 0                  no-reflow   DISEASE            [C0232347]
# 1                  diltiazem  CHEMICAL  [C0012373, C0282138]
# 2                 nicorandil  CHEMICAL            [C0068700]
# 3  intramyocardial haematoma   DISEASE                  None
# 4                        IMH   DISEASE  [C3544398, C0027466]
# 5   congestive heart failure   DISEASE            [C0018802]
# 6                        IMH   DISEASE  [C3544398, C0027466]
# 7    ventricular tachycardia   DISEASE  [C0042514, C0344428]
# 8                   aneurysm   DISEASE  [C0002940, C0751003]
#
#                                      3
# 0                 No-Reflow Phenomenon
# 1                            diltiazem
# 2                           nicorandil
# 3                                 None
# 4  stress-induced mitochondrial fusion
# 5             Congestive heart failure
# 6  stress-induced mitochondrial fusion
# 7             Tachycardia, Ventricular
# 8                             Aneurysm

# %%
pd.DataFrame(entity_linker(nlp, example2))
# Out:
#                            0         1         2  \
# 0                   hematoma   DISEASE  C0018944
# 1                        IMH   DISEASE  C3544398
# 2    Ventricular tachycardia   DISEASE  C0042514
# 3                  diltiazem  CHEMICAL  C0012373
# 4                 nicorandil  CHEMICAL  C0068700
# 5   intramyocardial hematoma   DISEASE      None
# 6                        IMH   DISEASE  C3544398
# 7   congestive heart failure   DISEASE  C0018802
# 8                        IMH   DISEASE  C3544398
# 9    ventricular tachycardia   DISEASE  C0042514
# 10                  aneurysm   DISEASE  C0002940
# 11             heart failure   DISEASE  C0018801
#
#                                       3
# 0                              Hematoma
# 1   stress-induced mitochondrial fusion
# 2              Tachycardia, Ventricular
# 3                             diltiazem
# 4                            nicorandil
# 5                                  None
# 6   stress-induced mitochondrial fusion
# 7              Congestive heart failure
# 8   stress-induced mitochondrial fusion
# 9              Tachycardia, Ventricular
# 10                             Aneurysm
# 11                        Heart failure

# %%
df_res_2
# Out:
#          label                                               text  in_ds
# 0      DISEASE                     Complete occlusion of proximal      1
# 1      DISEASE                                           anterior      1
# 2      DISEASE                           Intramyocardial hematoma      1
# 3      DISEASE                                                IMH      1
# 4      DISEASE                           Congestive heart failure      1
# 5      DISEASE                            Ventricular tachycardia      1
# 6    PROCEDURE         primary percutaneous coronary intervention      1
# 7    PROCEDURE                                               pPCI      1
# 8      DISEASE  completely occluded proximal left anterior des...      1
# 9   MEDICATION                                          diltiazem      1
# 10  MEDICATION                                         nicorandil      1
# 11   PROCEDURE                                     echocardiogram      1
# 12     DISEASE                           intramyocardial hematoma      1
# 14     DISEASE                           congestive heart failure      1
# 16     DISEASE                            ventricular tachycardia      1
# 17     SYMPTOM                                                 EF      1
# 18     DISEASE                                    apical aneurysm      1
# 19     DISEASE                                      heart failure      1

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

print(classification_report(df_tot["in_ds"], df_tot["in_cc"]))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         3
#          1.0       0.75      0.50      0.60        18
#
#     accuracy                           0.43        21
#    macro avg       0.38      0.25      0.30        21
# weighted avg       0.64      0.43      0.51        21

# %%
import numpy as np
import torch
from tqdm.auto import tqdm
from transformers import AutoTokenizer, AutoModel  

tokenizer = AutoTokenizer.from_pretrained("cambridgeltl/SapBERT-from-PubMedBERT-fulltext")  
model = AutoModel.from_pretrained("cambridgeltl/SapBERT-from-PubMedBERT-fulltext").cuda()

# replace with your own list of entity names
all_names = ["covid-19", "Coronavirus infection", "high fever", "Tumor of posterior wall of oropharynx"] 

bs = 128 # batch size during inference
all_embs = []
for i in tqdm(np.arange(0, len(all_names), bs)):
    toks = tokenizer.batch_encode_plus(all_names[i:i+bs], 
                                       padding="max_length", 
                                       max_length=25, 
                                       truncation=True,
                                       return_tensors="pt")
    toks_cuda = {}
    for k,v in toks.items():
        toks_cuda[k] = v.cuda()
    cls_rep = model(**toks_cuda)[0][:,0,:] # use CLS representation as the embedding
    all_embs.append(cls_rep.cpu().detach().numpy())

all_embs = np.concatenate(all_embs, axis=0)
all_embs
# Out:
# tokenizer_config.json:   0%|          | 0.00/198 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/462 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/226k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# array([[-0.64542013, -0.38714704, -0.21302737, ...,  0.23982963,
#          0.80409414,  0.423348  ],
#        [-1.188549  , -0.27455914,  0.28520218, ..., -0.12636967,
#          0.8062242 ,  0.06786634],
#        [-0.13091153,  0.4398695 , -0.14277072, ..., -0.317846  ,
#          0.37847674,  0.15484798],
#        [-0.86763877,  0.00546662, -0.38052037, ...,  0.18259029,
#          0.8963129 , -0.2953902 ]], dtype=float32)

# %%
# def assemble_ner_output_iob(ner_outputs):
#     entities = []
#     current_entity = None

#     for token in ner_outputs:
#         label = token["label"]
#         word = token["word"].replace("Ġ", " ")  # Handle byte-level tokens (e.g., RoBERTa)
#         score = token["score"]

#         if label.startswith("B-"):
#             if current_entity:
#                 # Save previous entity
#                 entities.append(current_entity)
#             # Start new entity
#             current_entity = {
#                 "label": label[2:],
#                 "text": word.strip(),
#                 "start": token["start"],
#                 "end": token["end"],
#                 "score": [score],
#             }
#         elif label.startswith("I-") and current_entity and label[2:] == current_entity["label"]:
#             # Continue current entity
#             current_entity["text"] += word
#             current_entity["end"] = token["end"]
#             current_entity["score"].append(score)
#         else:
#             if current_entity:
#                 entities.append(current_entity)
#                 current_entity = None
#             # You could also handle 'O' labels here if needed

#     if current_entity:
#         entities.append(current_entity)

#     # Average the scores
#     for ent in entities:
#         ent["score"] = sum(ent["score"]) / len(ent["score"])

#     return entities




assemble_ner_output_flat(proc_results)
# Out:
# [{'label': 'SYMPTOM',
#   'text': 'chest pain',
#   'start': 23,
#   'end': 33,
#   'score': 0.9915495216846466},
#  {'label': 'DISEASE',
#   'text': 'revascularised ischaemic heart disease',
#   'start': 68,
#   'end': 106,
#   'score': 0.9271806627511978},
#  {'label': 'DISEASE',
#   'text': 'drug allergies',
#   'start': 161,
#   'end': 175,
#   'score': 0.9905887842178345},
#  {'label': 'DISEASE',
#   'text': 'toxic habits',
#   'start': 180,
#   'end': 192,
#   'score': 0.988537460565567},
#  {'label': 'DISEASE',
#   'text': 'Diabetes mellitus type 2',
#   'start': 194,
#   'end': 218,
#   'score': 0.9867602944374084},
#  {'label': 'DISEASE',
#   'text': 'Hypercholesterolemia type dyslipidaemia',
#   'start': 248,
#   'end': 287,
#   'score': 0.96442209482193},
#  {'label': 'PROCEDURE',
#   'text': 'hygienic-dietary measures',
#   'start': 308,
#   'end': 333,
#   'score': 0.9714225729306539},
#  {'label': 'SYMPTOM',
#   'text': 'HIV positive',
#   'start': 335,
#   'end': 347,
#   'score': 0.6786492764949799},
#  {'label': 'DISEASE',
#   'text': 'Pneumocystis carinii pneumonia',
#   'start': 387,
#   'end': 417,
#   'score': 0.9301522506607903},
#  {'label': 'PROCEDURE',
#   'text': 'highly active antiretroviral therapy',
#   'start': 481,
#   'end': 517,
#   'score': 0.9598497226834297},
#  {'label': 'PROCEDURE',
#   'text': 'HAART',
#   'start': 519,
#   'end': 524,
#   'score': 0.8325951993465424},
#  {'label': 'SYMPTOM',
#   'text': 'HIV-RNA negative',
#   'start': 570,
#   'end': 586,
#   'score': 0.992913618683815},
#  {'label': 'PROCEDURE',
#   'text': 'right inguinal herniorrhaphy',
#   'start': 740,
#   'end': 768,
#   'score': 0.9822336614131928},
#  {'label': 'MEDICATION',
#   'text': 'abacavir/lamivudine',
#   'start': 791,
#   'end': 810,
#   'score': 0.8298500180244446},
#  {'label': 'MEDICATION',
#   'text': 'atazanavir',
#   'start': 831,
#   'end': 841,
#   'score': 0.9886014461517334},
#  {'label': 'MEDICATION',
#   'text': 'ritonavir',
#   'start': 858,
#   'end': 867,
#   'score': 0.9924434721469879},
#  {'label': 'MEDICATION',
#   'text': 'metformin',
#   'start': 884,
#   'end': 893,
#   'score': 0.9938622117042542},
#  {'label': 'SYMPTOM',
#   'text': 'oppressive central thoracic pain, radiating to the left upper limb',
#   'start': 966,
#   'end': 1032,
#   'score': 0.9901439590113503},
#  {'label': 'SYMPTOM',
#   'text': 'nausea',
#   'start': 1049,
#   'end': 1055,
#   'score': 0.9946171641349792},
#  {'label': 'SYMPTOM',
#   'text': 'profuse sweating',
#   'start': 1060,
#   'end': 1076,
#   'score': 0.993004560470581},
#  {'label': 'PROCEDURE',
#   'text': 'analgesic',
#   'start': 1139,
#   'end': 1148,
#   'score': 0.904019296169281},
#  {'label': 'SYMPTOM',
#   'text': 'pain',
#   'start': 1204,
#   'end': 1208,
#   'score': 0.9837386608123779},
#  {'label': 'PROCEDURE',
#   'text': 'electrocardiographic',
#   'start': 1273,
#   'end': 1293,
#   'score': 0.9042773097753525},
#  {'label': 'SYMPTOM',
#   'text': 'alterations',
#   'start': 1294,
#   'end': 1305,
#   'score': 0.7049643397331238},
#  {'label': 'DISEASE',
#   'text': 'ST-segment elevation acute coronary syndrome',
#   'start': 1322,
#   'end': 1366,
#   'score': 0.8483985885977745},
#  {'label': 'DISEASE',
#   'text': 'STEMI',
#   'start': 1368,
#   'end': 1373,
#   'score': 0.9510879814624786},
#  {'label': 'PROCEDURE',
#   'text': 'cardiac catheterisation',
#   'start': 1442,
#   'end': 1465,
#   'score': 0.9930561631917953},
#  {'label': 'PROCEDURE',
#   'text': 'PHYSICAL EXAMINATION',
#   'start': 1468,
#   'end': 1488,
#   'score': 0.9932298915726798},
#  {'label': 'SYMPTOM',
#   'text': 'Afebrile',
#   'start': 1490,
#   'end': 1498,
#   'score': 0.9946679174900055},
#  {'label': 'SYMPTOM',
#   'text': 'Conscious',
#   'start': 1626,
#   'end': 1635,
#   'score': 0.9879363179206848},
#  {'label': 'SYMPTOM',
#   'text': 'oriented',
#   'start': 1637,
#   'end': 1645,
#   'score': 0.9740850329399109},
#  {'label': 'SYMPTOM',
#   'text': 'cooperative',
#   'start': 1650,
#   'end': 1661,
#   'score': 0.9554343223571777},
#  {'label': 'SYMPTOM',
#   'text': 'Well hydrated',
#   'start': 1663,
#   'end': 1676,
#   'score': 0.9780410130818685},
#  {'label': 'SYMPTOM',
#   'text': 'perfused',
#   'start': 1681,
#   'end': 1689,
#   'score': 0.7443468570709229},
#  {'label': 'SYMPTOM',
#   'text': 'Regular general condition',
#   'start': 1691,
#   'end': 1716,
#   'score': 0.992823044459025},
#  {'label': 'SYMPTOM',
#   'text': 'affected by pain',
#   'start': 1718,
#   'end': 1734,
#   'score': 0.8583898941675822},
#  {'label': 'SYMPTOM',
#   'text': 'Eupneic at rest',
#   'start': 1736,
#   'end': 1751,
#   'score': 0.9933655858039856},
#  {'label': 'SYMPTOM',
#   'text': 'Jugular venous pressure normal',
#   'start': 1753,
#   'end': 1783,
#   'score': 0.9939662558691842},
#  {'label': 'PROCEDURE',
#   'text': 'Cardiac auscultation',
#   'start': 1785,
#   'end': 1805,
#   'score': 0.9234598278999329},
#  {'label': 'SYMPTOM',
#   'text': ': rhythmic',
#   'start': 1805,
#   'end': 1815,
#   'score': 0.9935017625490824},
#  {'label': 'SYMPTOM',
#   'text': 'murmurs',
#   'start': 1820,
#   'end': 1827,
#   'score': 0.992529034614563},
#  {'label': 'PROCEDURE',
#   'text': 'Pulmonary auscultation',
#   'start': 1829,
#   'end': 1851,
#   'score': 0.9877946376800537},
#  {'label': 'SYMPTOM',
#   'text': 'respiratory sounds preserved',
#   'start': 1853,
#   'end': 1881,
#   'score': 0.9880428910255432},
#  {'label': 'SYMPTOM',
#   'text': 'Abdomen: soft, depressible and non-painful',
#   'start': 1906,
#   'end': 1948,
#   'score': 0.9901867463038518},
#  {'label': 'SYMPTOM',
#   'text': 'Peristalsis present',
#   'start': 1950,
#   'end': 1969,
#   'score': 0.9918999195098877},
#  {'label': 'SYMPTOM',
#   'text': 'Lower',
#   'start': 1971,
#   'end': 1976,
#   'score': 0.86681067943573},
#  {'label': 'SYMPTOM',
#   'text': 'oed',
#   'start': 1993,
#   'end': 1996,
#   'score': 0.9847604632377625}]
