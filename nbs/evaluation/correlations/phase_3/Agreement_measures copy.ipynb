# %%
import pandas as pd
pd.set_option('display.max_columns', None)

def expand_and_concat_dicts(df, col):
    """
    Expand a column of dictionaries into separate columns and concatenate with the original dataframe.
    """

    # Expand the column of dictionaries into separate columns
    try:
        expanded_df = pd.DataFrame(df[col].apply(eval).tolist())
    except Exception as e:
        expanded_df = pd.DataFrame(df[col].tolist())
        
    # Rename the columns to avoid duplicates
    expanded_df.columns = [f"{col}_{colname}" for colname in expanded_df.columns]
    
    # Concatenate the expanded dataframe with the original dataframe
    concatenated_df = pd.concat([df, expanded_df], axis=1)
    concatenated_df = concatenated_df.drop(columns=[col])
        
    return concatenated_df

# %%
df_prometheus = pd.read_csv('output/samples/en/phase_3/prometheus_evaluation.tsv', sep='\t', dtype={"filenameid": str})
df_pairs = df_prometheus[["filenameid", "clinical_case", "discharge_summary"]]
df_human = pd.read_csv('output/samples/en/phase_3/human_eval.tsv', sep='\t', dtype={"doc_id": str})
df_human = df_human.rename(columns={"doc_id": "filenameid"})
df_human["Key Information CC"] = df_human["Key Information CC"].apply(eval)
df_human["Key Information DS"] = df_human["Key Information DS"].apply(eval)

cols_eval = ["Medical Entities Completeness", "Structure - Headers",	"Structure - Content", "Content Accuracy",	"Made-up Content", "Overall Quality"]
for col in cols_eval:
    df_human[col] = df_human[col].astype(int)
    
df_leti = df_human[df_human["annotator"] == "Leti"]
df_laura = df_human[df_human["annotator"] == "Laura"]


df_human.head()
# Out:
#    filenameid annotator                                 Key Information CC  \
# 0    27198691     Laura  [symptoms, signs and clinical findings, diseas...
# 1    29399767     Laura  [symptoms, signs and clinical findings, diseas...
# 2    29877258     Laura  [symptoms, signs and clinical findings, diseas...
# 3  29899452_1     Laura  [symptoms, signs and clinical findings, diseas...
# 4    30170386     Laura  [symptoms, signs and clinical findings, diseas...
#
#                                   Key Information DS  \
# 0  [symptoms, signs and clinical findings, diseas...
# 1  [symptoms, signs and clinical findings, diseas...
# 2  [symptoms, signs and clinical findings, diseas...
# 3  [symptoms, signs and clinical findings, diseas...
# 4  [symptoms, signs and clinical findings, sex, a...
#
#    Medical Entities Completeness  Structure - Headers  Structure - Content  \
# 0                              5                    5                    5
# 1                              5                    5                    5
# 2                              4                    5                    5
# 3                              4                    3                    3
# 4                              5                    4                    5
#
#    Content Accuracy  Made-up Content  Coherence  Overall Quality  \
# 0                 5                5      False                5
# 1                 4                4      False                4
# 2                 3                1      False                3
# 3                 3                2      False                2
# 4                 4                4      False                2
#
#                                             Feedback
# 0  The only thing I wanted to comment on is the d...
# 1  The final section Discharge instructions has b...
# 2  There are missing data of some clinical proced...
# 3  DS has confused the diagnoses with the medical...
# 4  Diagnosis:** Cutaneous Sarcoidosis (CS).  This...

# %%
df_human_tot = df_laura.merge(df_leti, on="filenameid", suffixes=("_laura", "_leti"))

for col in cols_eval:
    df_human_tot["diff_" + col] = (df_human_tot[f"{col}_laura"] - df_human_tot[f"{col}_leti"] ).abs()
df_human_tot["diff_Key Information DS"] = df_human_tot.apply(lambda row: set(row["Key Information DS_laura"]) - set(row["Key Information DS_leti"]), axis=1)
df_human_tot["diff_len_Key Information DS"] = df_human_tot["diff_Key Information DS"].apply(len)

df_human_tot["max_diff"] = df_human_tot[[f"diff_{col}" for col in cols_eval + ["len_Key Information DS"]]].max(axis=1)
df_human_tot["sum_diff"] = df_human_tot[[f"diff_{col}" for col in cols_eval + ["len_Key Information DS"]]].sum(axis=1)
df_human_tot = df_pairs.merge(df_human_tot, on="filenameid", how="left")
df_human_tot = df_human_tot.sort_values(by=["sum_diff", "max_diff"], ascending=[False, False])
df_human_tot
# Out:
#     filenameid                                      clinical_case  \
# 4     31056078  Initial presentation\nA 55-year-old, Caucasian...
# 6   29899452_1  The patient was a 29-year-old man with PIK3CA ...
# 15    31379463  Patient medical history\n\nThe described patie...
# 16    30170386  A 77-year-old man diagnosed with cutaneous sar...
# 3     29399767  A 54-year-old male had had a HeartMate 3™ impl...
# 25    29877258  A 35-year-old woman (gravida 1, para 1; uneven...
# 1     32864940  GSA, male, 55 years old, white, forklift opera...
# 22    36055898  We present the case of a 22-year-old female pa...
# 18    27198691  A 75-year-old man with permanent atrial fibril...
# 9     33782774  A 20-year-old man (height: 138 cm, weight: 39 ...
# 21  30971480_1  A 67‐year‐old woman with a recurrent leiomyosa...
# 14    31256189  A 68-year-old female first admitted to our hos...
# 17    33407125  A 62-year-old female underwent a diagnostic le...
# 0     31668014  A 67‐year‐old man treated with hemodialysis wa...
# 8   32351016_1  A 73‐year‐old female patient was hospitalized ...
# 10    38866580  A term male newborn with a gestational age of ...
# 11    33139369  The patient is a 56-year-old woman with a medi...
# 12    32434382  A 65-year-old female with a history of rheumat...
# 19    30567249  A 74-year-old man underwent primary percutaneo...
# 23    31377751  A 56-year-old male presented to the emergency ...
# 28  33823878_4  A 57-year-old male patient underwent HeartMate...
# 29    32541524  A 4-month-old male infant, after an uncomplica...
# 5     33544806  Clinical history\n\nFour years before the admi...
# 7     32305569  Our case patient is a 66-year-old man with a h...
# 13    31708703  In spring 1992, a 17-year-old boy presented at...
# 20    30700635  A 58-year-old female with no prior medical his...
# 27    30633184  A 63-year-old female was admitted to the Emerg...
# 2     35414581  Patient information\nA woman in her 70s diagno...
# 24    34946264  On Admission\n\nA 91-year-old woman with a his...
# 26    31939641  A 39-year-old man with a history of mild inter...
#
#                                     discharge_summary annotator_laura  \
# 4   **Discharge Summary**\n\n**Patient Information...           Laura
# 6   **Discharge Summary**\n\n**Patient Information...           Laura
# 15  **Discharge Summary**\n\n**Patient Information...           Laura
# 16  **Discharge Summary**\n\n**Patient Information...           Laura
# 3   **Discharge Summary**\n\n**Patient Information...           Laura
# 25  **Discharge Summary**\n\n**Patient Information...           Laura
# 1   **Discharge Summary**\n\n**Patient Information...           Laura
# 22  **Discharge Summary**\n\n**Patient Information...           Laura
# 18  **Discharge Summary**\n\n**Patient Information...           Laura
# 9   **Discharge Summary**\n\n**Patient Information...           Laura
# 21  **Discharge Summary**\n\n**Patient Information...           Laura
# 14  **Discharge Summary**\n\n**Patient Information...           Laura
# 17  **Discharge Summary**\n\n**Patient Information...           Laura
# 0   **Discharge Summary**\n\n**Patient Information...           Laura
# 8   **Discharge Summary**\n\n**Patient Information...           Laura
# 10  **Discharge Summary**\n\n**Patient Information...           Laura
# 11  **Discharge Summary**\n\n**Patient Information...           Laura
# 12  **Discharge Summary**\n\n**Patient Information...           Laura
# 19  **Discharge Summary**\n\n**Patient Information...           Laura
# 23  **Discharge Summary**\n\n**Patient Information...           Laura
# 28  **Discharge Summary**\n\n**Patient Information...           Laura
# 29  **Discharge Summary**\n\n**Patient Information...           Laura
# 5   **Discharge Summary**\n\n**Patient Information...           Laura
# 7   **Discharge Summary**\n\n**Patient Information...           Laura
# 13  **Discharge Summary**\n\n**Patient Information...           Laura
# 20  **Discharge Summary**\n\n**Patient Information...           Laura
# 27  **Discharge Summary**\n\n**Patient Information...           Laura
# 2   **Discharge Summary**\n\n**Patient Information...           Laura
# 24  **Discharge Summary**\n\n**Patient Information...           Laura
# 26  **Discharge Summary**\n\n**Patient Information...           Laura
#
#                              Key Information CC_laura  \
# 4   [clinical procedures, sex, age, symptoms, sign...
# 6   [symptoms, signs and clinical findings, diseas...
# 15  [symptoms, signs and clinical findings, medica...
# 16  [symptoms, signs and clinical findings, diseas...
# 3   [symptoms, signs and clinical findings, diseas...
# 25  [symptoms, signs and clinical findings, diseas...
# 1   [symptoms, signs and clinical findings, diseas...
# 22  [symptoms, signs and clinical findings, diseas...
# 18  [symptoms, signs and clinical findings, diseas...
# 9   [symptoms, signs and clinical findings, diseas...
# 21  [clinical procedures, sex, age, symptoms, sign...
# 14  [clinical procedures, sex, age, symptoms, sign...
# 17  [symptoms, signs and clinical findings, diseas...
# 0   [symptoms, signs and clinical findings, diseas...
# 8   [symptoms, signs and clinical findings, diseas...
# 10  [symptoms, signs and clinical findings, medica...
# 11  [symptoms, signs and clinical findings, diseas...
# 12  [symptoms, signs and clinical findings, diseas...
# 19  [diseases and co-morbidities, clinical procedu...
# 23  [symptoms, signs and clinical findings, medica...
# 28  [symptoms, signs and clinical findings, diseas...
# 29  [symptoms, signs and clinical findings, diseas...
# 5   [symptoms, signs and clinical findings, diseas...
# 7   [symptoms, signs and clinical findings, diseas...
# 13  [symptoms, signs and clinical findings, diseas...
# 20                    [clinical procedures, sex, age]
# 27  [symptoms, signs and clinical findings, diseas...
# 2   [symptoms, signs and clinical findings, diseas...
# 24  [symptoms, signs and clinical findings, diseas...
# 26  [symptoms, signs and clinical findings, diseas...
#
#                              Key Information DS_laura  \
# 4   [sex, age, past medical conditions, medication...
# 6   [symptoms, signs and clinical findings, diseas...
# 15  [symptoms, signs and clinical findings, medica...
# 16  [symptoms, signs and clinical findings, sex, a...
# 3   [symptoms, signs and clinical findings, diseas...
# 25  [symptoms, signs and clinical findings, diseas...
# 1   [symptoms, signs and clinical findings, diseas...
# 22  [symptoms, signs and clinical findings, diseas...
# 18  [symptoms, signs and clinical findings, diseas...
# 9   [symptoms, signs and clinical findings, diseas...
# 21  [clinical procedures, sex, age, past medical c...
# 14  [sex, age, diseases and co-morbidities, sympto...
# 17  [symptoms, signs and clinical findings, diseas...
# 0   [symptoms, signs and clinical findings, diseas...
# 8   [symptoms, signs and clinical findings, diseas...
# 10  [symptoms, signs and clinical findings, medica...
# 11  [symptoms, signs and clinical findings, diseas...
# 12  [symptoms, signs and clinical findings, diseas...
# 19  [sex, age, clinical procedures, diseases and c...
# 23  [symptoms, signs and clinical findings, medica...
# 28  [symptoms, signs and clinical findings, diseas...
# 29  [symptoms, signs and clinical findings, diseas...
# 5   [symptoms, signs and clinical findings, diseas...
# 7   [symptoms, signs and clinical findings, diseas...
# 13  [symptoms, signs and clinical findings, diseas...
# 20                    [clinical procedures, sex, age]
# 27  [symptoms, signs and clinical findings, diseas...
# 2   [symptoms, signs and clinical findings, diseas...
# 24  [symptoms, signs and clinical findings, diseas...
# 26  [symptoms, signs and clinical findings, diseas...
#
#     Medical Entities Completeness_laura  Structure - Headers_laura  \
# 4                                     2                          2
# 6                                     4                          3
# 15                                    3                          5
# 16                                    5                          4
# 3                                     5                          5
# 25                                    4                          5
# 1                                     3                          5
# 22                                    5                          5
# 18                                    5                          5
# 9                                     2                          4
# 21                                    5                          5
# 14                                    5                          5
# 17                                    5                          4
# 0                                     4                          5
# 8                                     4                          4
# 10                                    1                          5
# 11                                    4                          5
# 12                                    5                          5
# 19                                    5                          4
# 23                                    5                          5
# 28                                    5                          5
# 29                                    3                          5
# 5                                     2                          4
# 7                                     4                          4
# 13                                    4                          4
# 20                                    5                          5
# 27                                    5                          5
# 2                                     4                          5
# 24                                    5                          5
# 26                                    5                          5
#
#     Structure - Content_laura  Content Accuracy_laura  Made-up Content_laura  \
# 4                           1                       3                      4
# 6                           3                       3                      2
# 15                          4                       4                      4
# 16                          5                       4                      4
# 3                           5                       4                      4
# 25                          5                       3                      1
# 1                           3                       3                      4
# 22                          5                       4                      4
# 18                          5                       5                      5
# 9                           4                       4                      4
# 21                          5                       5                      4
# 14                          5                       5                      4
# 17                          5                       5                      4
# 0                           4                       2                      4
# 8                           5                       5                      4
# 10                          1                       2                      4
# 11                          4                       4                      4
# 12                          5                       5                      4
# 19                          5                       5                      4
# 23                          5                       5                      4
# 28                          5                       5                      4
# 29                          4                       4                      4
# 5                           1                       2                      4
# 7                           4                       4                      4
# 13                          4                       4                      4
# 20                          5                       5                      4
# 27                          5                       5                      5
# 2                           4                       5                      5
# 24                          5                       5                      5
# 26                          5                       5                      4
#
#     Coherence_laura  Overall Quality_laura  \
# 4             False                      2
# 6             False                      2
# 15            False                      2
# 16            False                      2
# 3             False                      4
# 25            False                      3
# 1             False                      2
# 22            False                      4
# 18            False                      5
# 9             False                      3
# 21            False                      4
# 14            False                      4
# 17            False                      4
# 0             False                      2
# 8             False                      4
# 10            False                      3
# 11            False                      3
# 12            False                      4
# 19            False                      3
# 23            False                      4
# 28            False                      4
# 29            False                      3
# 5             False                      3
# 7             False                      3
# 13            False                      4
# 20            False                      4
# 27            False                      4
# 2             False                      5
# 24            False                      5
# 26            False                      4
#
#                                        Feedback_laura annotator_leti  \
# 4   In the DS is missing some information about fa...           Leti
# 6   DS has confused the diagnoses with the medical...           Leti
# 15  DS: The patient was supplemented with 40 mmol ...           Leti
# 16  Diagnosis:** Cutaneous Sarcoidosis (CS).  This...           Leti
# 3   The final section Discharge instructions has b...           Leti
# 25  There are missing data of some clinical proced...           Leti
# 1   DS miss the duration of symptoms. In section m...           Leti
# 22  DS missed information about one procedure ( EC...           Leti
# 18  The only thing I wanted to comment on is the d...           Leti
# 9   The DS is very summarized, with important info...           Leti
# 21  It made up the  **Discharge Condition:** and *...           Leti
# 14  it made up the finals sections of "plan" and "...           Leti
# 17  The DS reflects very well the clinical case, i...           Leti
# 0   Diagnosis:** Worsening heart failure with redu...           Leti
# 8   The previous diseases of the patient are missi...           Leti
# 10  There’s an important amount of information in ...           Leti
# 11  An important procedure as intubation was misse...           Leti
# 12  Details of dosage of some medications are missing           Leti
# 19  The recommendations in DS are out place becaus...           Leti
# 23  the only section that was made of is " Dischar...           Leti
# 28  DS mad up the follow-up  and discharge instruc...           Leti
# 29  Part of the TAE procedure is missing in DS, so...           Leti
# 5   The DS is very summarized, with important info...           Leti
# 7   There's important information of the CC that i...           Leti
# 13  DS made up this sentence: Following this event...           Leti
# 20        It made up the final section  of follow-up            Leti
# 27  **Chief Complaint:** usually this section is n...           Leti
# 2   DS missed some information about the electroni...           Leti
# 24  DS is very accurate with all the laboratory re...           Leti
# 26  Assesment, plan and discharge instructions wer...           Leti
#
#                               Key Information CC_leti  \
# 4   [diseases and co-morbidities, medications, cli...
# 6   [diseases and co-morbidities, medications, sex...
# 15  [diseases and co-morbidities, medications, sex...
# 16  [symptoms, signs and clinical findings, diseas...
# 3   [symptoms, signs and clinical findings, medica...
# 25  [symptoms, signs and clinical findings, diseas...
# 1   [diseases and co-morbidities, medications, sex...
# 22  [diseases and co-morbidities, sex, age, past m...
# 18  [symptoms, signs and clinical findings, diseas...
# 9   [diseases and co-morbidities, sex, age, past m...
# 21  [symptoms, signs and clinical findings, diseas...
# 14  [symptoms, signs and clinical findings, diseas...
# 17  [symptoms, signs and clinical findings, diseas...
# 0   [diseases and co-morbidities, medications, sex...
# 8   [diseases and co-morbidities, medications, sex...
# 10  [diseases and co-morbidities, sex, age, past m...
# 11  [symptoms, signs and clinical findings, diseas...
# 12  [diseases and co-morbidities, medications, sex...
# 19  [symptoms, signs and clinical findings, diseas...
# 23  [diseases and co-morbidities, medications, cli...
# 28  [diseases and co-morbidities, sex, age, past m...
# 29  [diseases and co-morbidities, medications, sex...
# 5   [diseases and co-morbidities, sex, age, past m...
# 7   [diseases and co-morbidities, medications, sex...
# 13  [diseases and co-morbidities, medications, sex...
# 20  [symptoms, signs and clinical findings, diseas...
# 27  [symptoms, signs and clinical findings, diseas...
# 2   [diseases and co-morbidities, sex, age, past m...
# 24  [diseases and co-morbidities, sex, age, past m...
# 26  [symptoms, signs and clinical findings, diseas...
#
#                               Key Information DS_leti  \
# 4   [symptoms, signs and clinical findings, diseas...
# 6   [diseases and co-morbidities, medications, cli...
# 15  [symptoms, signs and clinical findings, diseas...
# 16  [symptoms, signs and clinical findings, diseas...
# 3   [symptoms, signs and clinical findings, medica...
# 25  [symptoms, signs and clinical findings, diseas...
# 1   [symptoms, signs and clinical findings, diseas...
# 22  [symptoms, signs and clinical findings, diseas...
# 18  [symptoms, signs and clinical findings, diseas...
# 9   [symptoms, signs and clinical findings, diseas...
# 21  [symptoms, signs and clinical findings, diseas...
# 14  [symptoms, signs and clinical findings, diseas...
# 17  [symptoms, signs and clinical findings, diseas...
# 0   [symptoms, signs and clinical findings, diseas...
# 8   [symptoms, signs and clinical findings, diseas...
# 10  [symptoms, signs and clinical findings, diseas...
# 11  [symptoms, signs and clinical findings, diseas...
# 12  [symptoms, signs and clinical findings, diseas...
# 19  [symptoms, signs and clinical findings, diseas...
# 23  [symptoms, signs and clinical findings, diseas...
# 28  [symptoms, signs and clinical findings, diseas...
# 29  [symptoms, signs and clinical findings, diseas...
# 5   [symptoms, signs and clinical findings, diseas...
# 7   [symptoms, signs and clinical findings, diseas...
# 13  [symptoms, signs and clinical findings, diseas...
# 20  [symptoms, signs and clinical findings, diseas...
# 27  [symptoms, signs and clinical findings, diseas...
# 2   [symptoms, signs and clinical findings, diseas...
# 24  [symptoms, signs and clinical findings, diseas...
# 26  [symptoms, signs and clinical findings, diseas...
#
#     Medical Entities Completeness_leti  Structure - Headers_leti  \
# 4                                    4                         4
# 6                                    4                         5
# 15                                   2                         2
# 16                                   5                         5
# 3                                    4                         3
# 25                                   5                         5
# 1                                    2                         4
# 22                                   4                         5
# 18                                   5                         3
# 9                                    3                         4
# 21                                   5                         5
# 14                                   5                         4
# 17                                   5                         5
# 0                                    3                         5
# 8                                    4                         4
# 10                                   1                         4
# 11                                   4                         4
# 12                                   5                         5
# 19                                   5                         3
# 23                                   5                         5
# 28                                   5                         5
# 29                                   3                         5
# 5                                    2                         4
# 7                                    4                         4
# 13                                   4                         5
# 20                                   5                         5
# 27                                   5                         5
# 2                                    4                         5
# 24                                   5                         5
# 26                                   5                         5
#
#     Structure - Content_leti  Content Accuracy_leti  Made-up Content_leti  \
# 4                          3                      4                     5
# 6                          3                      3                     5
# 15                         2                      5                     5
# 16                         5                      5                     5
# 3                          5                      5                     5
# 25                         3                      4                     3
# 1                          2                      4                     4
# 22                         4                      5                     5
# 18                         5                      5                     4
# 9                          2                      4                     4
# 21                         3                      5                     5
# 14                         4                      5                     5
# 17                         5                      5                     5
# 0                          4                      2                     4
# 8                          4                      4                     4
# 10                         1                      2                     4
# 11                         4                      4                     4
# 12                         4                      4                     4
# 19                         5                      5                     5
# 23                         5                      5                     5
# 28                         5                      5                     5
# 29                         4                      4                     5
# 5                          1                      2                     4
# 7                          4                      4                     4
# 13                         4                      4                     4
# 20                         5                      5                     5
# 27                         5                      5                     5
# 2                          4                      5                     5
# 24                         5                      5                     5
# 26                         5                      5                     4
#
#     Coherence_leti  Overall Quality_leti  \
# 4            False                     3
# 6            False                     4
# 15           False                     2
# 16           False                     5
# 3            False                     4
# 25            True                     3
# 1            False                     3
# 22           False                     5
# 18           False                     4
# 9            False                     3
# 21           False                     4
# 14           False                     4
# 17           False                     5
# 0            False                     3
# 8            False                     4
# 10           False                     2
# 11           False                     4
# 12           False                     4
# 19            True                     3
# 23           False                     5
# 28           False                     5
# 29           False                     4
# 5            False                     2
# 7            False                     4
# 13           False                     4
# 20            True                     4
# 27           False                     4
# 2            False                     5
# 24           False                     5
# 26           False                     4
#
#                                         Feedback_leti  \
# 4                      Demasiado resumido en general.
# 6   No menciona la dilatación de VI ni la elevació...
# 15           Demasiado resumido, no bien estructurado
# 16                                         Sin pegas
# 3   Diagnosis:** Permanent atrial fibrillation wit...
# 25  La paciente acude a revisión del HeartMate no ...
# 1                     a lot of information is missed
# 22                                         well done
# 18  Podría mejorar los titulos de cada sección. El...
# 9   very summarized, important information is mnis...
# 21  Diagnosis debería aparecer al final antes de d...
# 14  - Diagnosis of hepatocellular carcinoma (HCC) ...
# 17                                         Well done
# 0               Se pierde mucha información sobre HF
# 8    some information related to mesurment is missed
# 10                       a lot of information missing
# 11              some missing information: intubation
# 12                                          Well done
# 19  El diagnóstico lo pondía la final y añadiría q...
# 23                                          Muy bien
# 28                                          well done
# 29  lack of infomation in TAE procedure, imaging s...
# 5   a lot of infornation is missing, very summarized
# 7   information related test and management is mis...
# 13  Made up: decline cardiac function and recommen...
# 20  Lo único ue me sobra es el último follow-up po...
# 27  Se ha inventado todos los fármacos de el Medic...
# 2                                          well done
# 24                                          well done
# 26  Assesment, plan and discharge instructions wer...
#
#     diff_Medical Entities Completeness  diff_Structure - Headers  \
# 4                                    2                         2
# 6                                    0                         2
# 15                                   1                         3
# 16                                   0                         1
# 3                                    1                         2
# 25                                   1                         0
# 1                                    1                         1
# 22                                   1                         0
# 18                                   0                         2
# 9                                    1                         0
# 21                                   0                         0
# 14                                   0                         1
# 17                                   0                         1
# 0                                    1                         0
# 8                                    0                         0
# 10                                   0                         1
# 11                                   0                         1
# 12                                   0                         0
# 19                                   0                         1
# 23                                   0                         0
# 28                                   0                         0
# 29                                   0                         0
# 5                                    0                         0
# 7                                    0                         0
# 13                                   0                         1
# 20                                   0                         0
# 27                                   0                         0
# 2                                    0                         0
# 24                                   0                         0
# 26                                   0                         0
#
#     diff_Structure - Content  diff_Content Accuracy  diff_Made-up Content  \
# 4                          2                      1                     1
# 6                          0                      0                     3
# 15                         2                      1                     1
# 16                         0                      1                     1
# 3                          0                      1                     1
# 25                         2                      1                     2
# 1                          1                      1                     0
# 22                         1                      1                     1
# 18                         0                      0                     1
# 9                          2                      0                     0
# 21                         2                      0                     1
# 14                         1                      0                     1
# 17                         0                      0                     1
# 0                          0                      0                     0
# 8                          1                      1                     0
# 10                         0                      0                     0
# 11                         0                      0                     0
# 12                         1                      1                     0
# 19                         0                      0                     1
# 23                         0                      0                     1
# 28                         0                      0                     1
# 29                         0                      0                     1
# 5                          0                      0                     0
# 7                          0                      0                     0
# 13                         0                      0                     0
# 20                         0                      0                     1
# 27                         0                      0                     0
# 2                          0                      0                     0
# 24                         0                      0                     0
# 26                         0                      0                     0
#
#     diff_Overall Quality                  diff_Key Information DS  \
# 4                      1                                       {}
# 6                      2  {symptoms, signs and clinical findings}
# 15                     0                                       {}
# 16                     3                                       {}
# 3                      0            {diseases and co-morbidities}
# 25                     0                                       {}
# 1                      1                                       {}
# 22                     1                                       {}
# 18                     1                                       {}
# 9                      0                                       {}
# 21                     0                                       {}
# 14                     0                                       {}
# 17                     1                                       {}
# 0                      1                                       {}
# 8                      0                                       {}
# 10                     1                                       {}
# 11                     1                                       {}
# 12                     0                                       {}
# 19                     0                                       {}
# 23                     1                                       {}
# 28                     1                                       {}
# 29                     1                                       {}
# 5                      1                                       {}
# 7                      1                                       {}
# 13                     0                                       {}
# 20                     0                                       {}
# 27                     0                            {medications}
# 2                      0                                       {}
# 24                     0                                       {}
# 26                     0                                       {}
#
#     diff_len_Key Information DS  max_diff  sum_diff
# 4                             0         2         9
# 6                             1         3         8
# 15                            0         3         8
# 16                            0         3         6
# 3                             1         2         6
# 25                            0         2         6
# 1                             0         1         5
# 22                            0         1         5
# 18                            0         2         4
# 9                             0         2         3
# 21                            0         2         3
# 14                            0         1         3
# 17                            0         1         3
# 0                             0         1         2
# 8                             0         1         2
# 10                            0         1         2
# 11                            0         1         2
# 12                            0         1         2
# 19                            0         1         2
# 23                            0         1         2
# 28                            0         1         2
# 29                            0         1         2
# 5                             0         1         1
# 7                             0         1         1
# 13                            0         1         1
# 20                            0         1         1
# 27                            1         1         1
# 2                             0         0         0
# 24                            0         0         0
# 26                            0         0         0

# %%
def print_example(i):
    example1 = df_human_tot.iloc[i]

    print(f"Example filenameid: {example1['filenameid']}")
    print("\n"*2)
    print(f"Clinical Case:\n{example1['clinical_case']}")
    print("\n"*2)
    print(f"Discharge Summary:\n {example1['discharge_summary']}")
    print("\n"*2)

    # print("Scores from Laura:")
    for col in cols_eval:
        print(f"{col}:\t Laura -- {example1[f'{col}_laura']}\t Leti -- {example1[f'{col}_leti']}")
    
    # print(f"diff_Key Information CC:\t Laura -- {example1[f'diff_len_Key Information CC']}\nLeti -- {example1[f'diff_len_Key Information CC']}")

    
    print("\n"*2)
    print("Feedback Laura:", example1["Feedback_laura"])
    print("Feedback Leti:", example1["Feedback_leti"])
    
print_example(-3)  # Print the last example
# Out:
# Example filenameid: 35414581
#
#
#
# Clinical Case:
# Patient information
# A woman in her 70s diagnosed with HF in 1999, having comorbidities such as chronic obstructive pulmonary disease, asthma, hypertension, diabetes and kidney failure (stage 4). The patient lived with a full-time carer, in one of the most deprived (decile 1 for both the Index of Multiple Deprivation and the Health Deprivation and Disability Domain) areas of England. As per usual practice, the patient was mostly looked after by her general practitioner (GP).
#
# The patient and her son provided informed consent to use her anonymised data for research purposes. The patient’s son consented to the access and use of the patient’s medical records after she had passed away. The data were collected as part of post-market surveillance activities in the UK.
#
# Treatment
# Device information
# The Heartfelt device (Heartfelt Technologies) and connected weighing scales (Xiaomi Smart Scales, Anhui Huami Information Technologies) were installed in the patient’s home and connected via the internet to cloud-based servers for continuous monitoring.
#
# The Heartfelt device is an automated, non-invasive, remote volume-monitoring system that uses 3D sensors to automatically measure the volume of the foot/lower leg and generates alerts when the foot volume increases. In a hospital study, the volumes measured using the Heartfelt device were compared with volumes measured using water displacement (gold standard to measure foot volume) and the Heartfelt device had a SE of measurement of ±12.6 mL.
#
# The 3D sensor captures images at a rate of 30 images per second, which are censored at knee height. Measurements are then processed using artificial intelligence in cloud servers. A selection of 4–8 3D images are used to calculate the volume, these images may have been captured over a period of a few minutes or hours depending on the patient’s routine in the room where the device is located. When an increase in volume is detected beyond baseline level (oedema), an alert is generated. The alert can be sent to the patient, their carer or their clinical team. The innovation of the Heartfelt device is that it requires no specific action from the patient unlike other telemonitoring technologies that require patients to interact or comply with instructions for use. Even weighing scales, which are used as part of standard care for the management of HF, require a level of compliance from patients.
#
# Timeline
# The Heartfelt device was installed in the patient’s house at a location and height to allow for optimal data collection and it successfully collected and transmitted data for fifteen months (November 2018 to January 2020; until the patient’s first hospital admission. A few more days of data were collected between discharge and the second admission. 3D images of feet/lower legs of the patient were automatically captured, censored, encrypted and transmitted securely over the internet to cloud-based servers for final processing to generate daily foot/lower leg volumes. These daily data points were monitored by trained operators and our setup ensured that no change was required in the patient’s lifestyle or standard care and she could be monitored safely in her home.
#
# First alert
# Following an increase in lower limb volume starting in late December 2019, an alert was raised on third Jan 2020 and the patient and her carer were informed as per the agreed contact method with the patient and her family at the time of installation. A follow-up alert was generated on 11 January 2020 and the patient was visited by a GP on 12 January 2020 on patient’s request, at which point peripheral oedema was confirmed up to the knee. Given that the patient had kidney failure and was on the maximal tolerated dose of oral diuretic (120 mg furosemide/day and 50 mg/day spironolactone), the ongoing medications were kept the same.
#
# First hospitalisation
# For the next few days, the patient’s condition did not improve and the GP was called for a home visit again. Peripheral oedema was noted as thigh-high and ascites, and the patient also suffered severe shortness of breath after five steps. The GP and patient agreed that the best course of action would be to get IV diuretic to help reduce congestion. In the patient’s area, this can only be done through an admission. Therefore the GP planned for the patient to be admitted on 16 January 2020. The patient was admitted as a non-urgent admission to a cardiology ward and HF decompensation was subsequently confirmed. The patient remained hospitalised and was discharged on 7 February 2020 with further treatment of high-dose diuretics.
#
# Second alert
# The system logged measurements following discharge, which indicated the patient was not euvolaemic and her feet were still swollen. The patient was then bedbound for several days, and on 12 February 2020 a further measurement with >300 mL increase was made, and the patient was informed.
#
# Second hospitalisation
# After the second alert, the condition of the patient deteriorated rapidly. New diuretics were prescribed by her GP, 5 mg amiloride and 2.5 mg metolazone and furosemide was reduced to 160 mg/day. She was then admitted to hospital again on 15 February 2020 as a non-urgent admission. The patient remained in hospital until the 23 February 2020 and began to receive palliative care from 24 February 2020 onwards. The patient subsequently died on 8 March 2020.
#
# Follow-up and outcomes
# The volume trends and alerts generated throughout the 15 months for the patient. Alerts were generated both times in a timely fashion to prevent the need for an emergency hospital admission. The device has successfully provided volume data on 97.7% of days (over fifteen months) and the volume capture did not drop off over time.
#
#
#
#
#
# Discharge Summary:
#  **Discharge Summary**
#
# **Patient Information:**
# - **Patient:** Female, 70s
# - **Diagnosis:** Heart Failure (HF) since 1999
# - **Comorbidities:** Chronic Obstructive Pulmonary Disease, Asthma, Hypertension, Diabetes, Stage 4 Kidney Failure
# - **Living Situation:** Resided with a full-time carer in a deprived area of England, primarily managed by her General Practitioner (GP).
#
# **Consent for Data Use:**
# - Informed consent was obtained from the patient and her son for the use of anonymized data for research purposes. The son consented to access the patient's medical records posthumously.
#
# **Treatment Overview:**
# - **Device Utilized:** Heartfelt device (Heartfelt Technologies) for remote volume monitoring, alongside Xiaomi Smart Scales.
# - **Functionality:** The Heartfelt device employs 3D sensors for non-invasive monitoring of lower limb volume, generating alerts for volume increases indicative of edema. The device operated effectively for 15 months, from November 2018 to January 2020.
#
# **Monitoring Timeline:**
# - **Installation:** Device installed for optimal data collection.
# - **First Alert:** Triggered on January 3, 2020, due to increased lower limb volume. Confirmed peripheral edema up to the knee during GP visit on January 12, 2020.
# - **First Hospitalization:** Admitted on January 16, 2020, for IV diuretics due to HF decompensation; discharged on February 7, 2020.
#
# **Second Alert and Hospitalization:**
# - **Second Alert:** Noted on February 12, 2020, indicating significant volume increase post-discharge.
# - **Second Hospitalization:** Admitted on February 15, 2020, with deteriorating condition. Palliative care initiated on February 24, 2020. The patient passed away on March 8, 2020.
#
# **Outcomes:**
# - The Heartfelt device successfully monitored volume trends, generating timely alerts that prevented emergency admissions. Volume data was captured on 97.7% of days over the monitoring period, demonstrating consistent performance.
#
# **Conclusion:**
# The patient received comprehensive monitoring and care throughout her treatment, with the Heartfelt device playing a crucial role in managing her heart failure and related complications.
#
#
#
# Medical Entities Completeness:	 Laura -- 4	 Leti -- 4
# Structure - Headers:	 Laura -- 5	 Leti -- 5
# Structure - Content:	 Laura -- 4	 Leti -- 4
# Content Accuracy:	 Laura -- 5	 Leti -- 5
# Made-up Content:	 Laura -- 5	 Leti -- 5
# Overall Quality:	 Laura -- 5	 Leti -- 5
#
#
#
# Feedback Laura: DS missed some information about the electronic device, but it's not relevant for the clinical case
# Feedback Leti: well done

# %%
df_diff = df_human_tot[["filenameid"] + [f"diff_{col}" for col in cols_eval + ["len_Key Information DS"]] + ["sum_diff", "max_diff"]]
print(df_diff.iloc[:3].T.reset_index().to_latex(index=False, escape=False, column_format="l" + "r" * (len(cols_eval) + 2), caption="Differences in evaluation scores between annotators Laura and Leti. The columns 'diff_*' represent the absolute difference in scores for each evaluation criterion, while 'sum_diff' and 'max_diff' summarize the differences across all criteria.", label="tab:human_eval_differences"))
# Out:
# \begin{table}
# \caption{Differences in evaluation scores between annotators Laura and Leti. The columns 'diff_*' represent the absolute difference in scores for each evaluation criterion, while 'sum_diff' and 'max_diff' summarize the differences across all criteria.}
# \label{tab:human_eval_differences}
# \begin{tabular}{lrrrrrrrr}
# \toprule
# index & 4 & 6 & 15 \\
# \midrule
# filenameid & 31056078 & 29899452_1 & 31379463 \\
# diff_Medical Entities Completeness & 2 & 0 & 1 \\
# diff_Structure - Headers & 2 & 2 & 3 \\
# diff_Structure - Content & 2 & 0 & 2 \\
# diff_Content Accuracy & 1 & 0 & 1 \\
# diff_Made-up Content & 1 & 3 & 1 \\
# diff_Overall Quality & 1 & 2 & 0 \\
# diff_len_Key Information DS & 0 & 1 & 0 \\
# sum_diff & 9 & 8 & 8 \\
# max_diff & 2 & 3 & 3 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
df_diff = df_human_tot[["filenameid"] + [f"diff_{col}" for col in cols_eval + ["len_Key Information DS"]] + ["sum_diff", "max_diff"]]
print(df_diff.iloc[-3:-1].T.reset_index().to_latex(index=False, escape=False, column_format="l" + "r" * 2))
# Out:
# \begin{tabular}{lrr}
# \toprule
# index & 2 & 24 \\
# \midrule
# filenameid & 35414581 & 34946264 \\
# diff_Medical Entities Completeness & 0 & 0 \\
# diff_Structure - Headers & 0 & 0 \\
# diff_Structure - Content & 0 & 0 \\
# diff_Content Accuracy & 0 & 0 \\
# diff_Made-up Content & 0 & 0 \\
# diff_Overall Quality & 0 & 0 \\
# diff_len_Key Information DS & 0 & 0 \\
# sum_diff & 0 & 0 \\
# max_diff & 0 & 0 \\
# \bottomrule
# \end{tabular}
