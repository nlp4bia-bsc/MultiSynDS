# %%
from transformers import pipeline
import torch
import os

import seaborn as sns
import matplotlib.pyplot as plt
from src.metrics import compute_score
from src.generate import model_evaluation, model_evaluation_cot
from scipy.stats import pearsonr

OUTPUT_FOLDER = "output/samples/en/phase_1/model/base_prompt/two_shot_cot"
if not os.path.exists(OUTPUT_FOLDER):
    os.makedirs(OUTPUT_FOLDER)
    
# model_id = "meta-llama/Llama-3.2-3B-Instruct"
model_id = "/gpfs/projects/bsc14/abecerr1/hub/models--meta-llama--Llama-3.2-3B-Instruct/snapshots/0cb88a4f764b7a12671c53f0838cd831a0843b95"
pipe = pipeline(
    "text-generation",
    model=model_id,
    torch_dtype=torch.bfloat16,
    # device="cuda",
    device_map="auto",
)
# Out:
# Loading checkpoint shards: 100%|██████████| 2/2 [00:03<00:00,  1.56s/it]
# Device set to use cuda:0

# %%
model_evaluation_cot(pipe, clinical_case="He is sick and has headache and a fever", discharge_summary="He is sick and a fever", filenames=[])
# Out:
# No human evaluation file provided. Skipping example generation.
# {'Content Relevance': 2,
#  'Information Completeness': 3,
#  'Clarity and Structure': 2,
#  'Content Accuracy': 3,
#  'Hallucinations': 4,
#  'Impact of Hallucinations': 4,
#  'Relevance to Practice': 2,
#  'Overall Quality': 2,
#  'Positive/Negative highlights of generation process': 'Summary lacks key details',
#  'Other comments on Generated/Original data sources': 'Generated summary lacks original clinical case details'}

# %%
# Evaluate phase 1 data
from src.data import files_to_df
import os

data_path = "output/samples/en/phase_2/"
k_shot_filenames = ["33857916", "31378248"]
eval_filenames = ['34530632', '32997782', '30785587', '26989133', '29617510', '30072860', '30930460', '31049155', '31056078', '31204375', '31486515', '31512669', '31557359']
human_eval_file="output/samples/en/phase_2/human_eval.csv"
base_filenames_path="output/samples/en/phase_2"

sample_df_gen = files_to_df(os.path.join(data_path, "generated"))
sample_df_gen["filenameid"] = sample_df_gen["filenameid"].str.replace("_transformed_step1", "")

sample_df_orig = files_to_df(os.path.join(data_path, "original"))
sample_df = sample_df_orig.merge(sample_df_gen, on="filenameid", suffixes=("_orig", "_gen"))

sample_df = sample_df[sample_df["filenameid"].isin(eval_filenames)]
sample_df
# Out:
#    filenameid                                          text_orig  \
# 2    29617510  An 81-year-old male patient was admitted due t...
# 4    31204375  A 92-year-old man was admitted to our hospital...
# 7    31056078  Initial presentation\nA 55-year-old, Caucasian...
# 8    31486515  A 57-year-old Caucasian man was admitted to th...
# 12   31512669  A 25-year-old male who presented with acute on...
# 13   32997782  In March 2017, a 67-year-old man with hyperten...
# 14   31557359  A 61‐year‐old man, diabetic and hypertensive, ...
# 15   26989133  A previously fit and healthy 75-year-old Chine...
# 16   31049155  A 30-year-old woman with a history of neonatal...
# 21   34530632  A 70-year-old man (170 cm, 48 kg, American Soc...
# 26   30785587  A 51-year-old male, hypertensive patient, a fo...
# 30   30930460  A 56-year-old male at the age of 49 years deve...
#
#                                              text_gen
# 2   **Discharge Summary**\n\n**Patient Information...
# 4   **Discharge Summary**\n\n**Patient Information...
# 7   **Discharge Summary**\n\n**Patient Information...
# 8   **Discharge Summary**\n\n**Patient Information...
# 12  **Discharge Summary**\n\n**Patient Information...
# 13  **Discharge Summary**\n\n**Patient Information...
# 14  **Discharge Summary**\n\n**Patient Information...
# 15  **Discharge Summary**\n\n**Patient Information...
# 16  **Discharge Summary**\n\n**Patient Information...
# 21  **Discharge Summary**\n\n**Patient Information...
# 26  **Discharge Summary**\n\n**Patient Information...
# 30  **Discharge Summary**\n\n**Patient Information...

# %%
import pandas as pd
from tqdm import tqdm
tqdm.pandas()

filenames = []
d_gen = sample_df.progress_apply(lambda x: model_evaluation_cot(pipe, x["text_orig"], x["text_gen"], k_shot_filenames, "hf", human_eval_file=human_eval_file, base_filenames_path=base_filenames_path),
                                    axis=1)
# Out:
#  83%|████████▎ | 10/12 [01:09<00:14,  7.03s/it]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 100%|██████████| 12/12 [01:30<00:00,  7.56s/it]

# %%
df_metrics = pd.DataFrame(d_gen.tolist(), index=sample_df.index)
df_model_eval = pd.concat([sample_df, df_metrics], axis=1)
df_model_eval
# Out:
#    filenameid                                          text_orig  \
# 2    29617510  An 81-year-old male patient was admitted due t...
# 4    31204375  A 92-year-old man was admitted to our hospital...
# 7    31056078  Initial presentation\nA 55-year-old, Caucasian...
# 8    31486515  A 57-year-old Caucasian man was admitted to th...
# 12   31512669  A 25-year-old male who presented with acute on...
# 13   32997782  In March 2017, a 67-year-old man with hyperten...
# 14   31557359  A 61‐year‐old man, diabetic and hypertensive, ...
# 15   26989133  A previously fit and healthy 75-year-old Chine...
# 16   31049155  A 30-year-old woman with a history of neonatal...
# 21   34530632  A 70-year-old man (170 cm, 48 kg, American Soc...
# 26   30785587  A 51-year-old male, hypertensive patient, a fo...
# 30   30930460  A 56-year-old male at the age of 49 years deve...
#
#                                              text_gen  Content Relevance  \
# 2   **Discharge Summary**\n\n**Patient Information...                  5
# 4   **Discharge Summary**\n\n**Patient Information...                  5
# 7   **Discharge Summary**\n\n**Patient Information...                  5
# 8   **Discharge Summary**\n\n**Patient Information...                  5
# 12  **Discharge Summary**\n\n**Patient Information...                  5
# 13  **Discharge Summary**\n\n**Patient Information...                  4
# 14  **Discharge Summary**\n\n**Patient Information...                  5
# 15  **Discharge Summary**\n\n**Patient Information...                  5
# 16  **Discharge Summary**\n\n**Patient Information...                  5
# 21  **Discharge Summary**\n\n**Patient Information...                  5
# 26  **Discharge Summary**\n\n**Patient Information...                  5
# 30  **Discharge Summary**\n\n**Patient Information...                  5
#
#     Information Completeness  Clarity and Structure  Content Accuracy  \
# 2                          5                      5                 5
# 4                          5                      5                 5
# 7                          5                      5                 5
# 8                          5                      5                 5
# 12                         5                      5                 5
# 13                         4                      5                 4
# 14                         5                      5                 5
# 15                         5                      5                 5
# 16                         5                      5                 5
# 21                         5                      5                 5
# 26                         5                      5                 5
# 30                         5                      5                 5
#
#     Hallucinations  Impact of Hallucinations  Relevance to Practice  \
# 2                1                         1                      5
# 4                1                         1                      5
# 7                1                         1                      5
# 8                1                         1                      5
# 12               1                         1                      5
# 13               1                         1                      4
# 14               1                         1                      5
# 15               1                         1                      5
# 16               1                         1                      5
# 21               1                         1                      5
# 26               1                         1                      5
# 30               1                         1                      5
#
#     Overall Quality Positive highlights of generation process  \
# 2                 4                          Good structure.
# 4                 4                          Good structure.
# 7                 4                          Good structure.
# 8                 4                          Good structure.
# 12                4                          Good structure.
# 13                4                          Good structure.
# 14                4                          Good structure.
# 15                4                          Good structure.
# 16                4                          Good structure.
# 21                4                          Good structure.
# 26                4        Good structure and clear diagnosis
# 30                4                          Good structure.
#
#             Negative highlights of generation process  \
# 2   Lack of information related with clinical cour...
# 4   Lack of information related with clinical cour...
# 7   Lack of information related with clinical cour...
# 8   Lack of information related with clinical cour...
# 12  Lack of information related with clinical cour...
# 13  Lack of information related with clinical cour...
# 14  Lack of information related with clinical cour...
# 15  Lack of information related with clinical cour...
# 16  Lack of information related with clinical cour...
# 21  Lack of information related with clinical cour...
# 26  Lack of information on patient's long-term out...
# 30  Lack of information related with clinical cour...
#
#    Other comments on Generated/Original data sources
# 2
# 4
# 7
# 8
# 12
# 13
# 14
# 15
# 16
# 21
# 26
# 30

# %%
df_model_eval.to_csv(os.path.join(OUTPUT_FOLDER, "model_evaluation.csv"), index=False)

# %% [markdown]
# # Load Human Evaluation

# %%
he_path = "output/samples/en/phase_2/human_eval.csv"
df_human_eval = pd.read_csv(he_path)
df_human_eval = df_human_eval.iloc[:, 2:]
df_human_eval.columns = ["filenameid", 'Content Relevance', 'Information Completeness', 'Clarity and Structure', 'Content Accuracy',\
       'Hallucinations', 'Impact of Hallucinations', 'Relevance to Practice', 'Overall Quality',\
       'Positive highlights of generation process', 'Negative highlights of generation process', 'Other comments on Generated/Original data sources'\
       ]
df_human_eval["filenameid"] = df_human_eval["filenameid"].astype(str) 
df_human_eval = df_human_eval[df_human_eval["filenameid"].isin(eval_filenames)]
df_human_eval
# Out:
#    filenameid  Content Relevance  Information Completeness  \
# 1    34530632                  5                         4
# 2    32997782                  4                         2
# 4    30785587                  1                         1
# 5    26989133                  5                         4
# 6    29617510                  4                         4
# 7    30072860                  4                         3
# 8    30930460                  4                         3
# 9    31049155                  5                         5
# 10   31056078                  5                         5
# 11   31204375                  4                         3
# 12   31486515                  5                         5
# 13   31512669                  5                         5
# 14   31557359                  5                         5
#
#     Clarity and Structure  Content Accuracy  Hallucinations  \
# 1                       5                 5               1
# 2                       5                 4               1
# 4                       2                 2               1
# 5                       5                 5               1
# 6                       4                 5               1
# 7                       4                 3               1
# 8                       4                 3               1
# 9                       5                 5               1
# 10                      3                 5               1
# 11                      4                 4               1
# 12                      4                 4               1
# 13                      4                 4               1
# 14                      4                 5               1
#
#     Impact of Hallucinations  Relevance to Practice  Overall Quality  \
# 1                          1                      5                4
# 2                          1                      2                3
# 4                          1                      1                2
# 5                          1                      5                5
# 6                          1                      5                4
# 7                          1                      3                3
# 8                          1                      3                3
# 9                          1                      5                5
# 10                         1                      3                4
# 11                         1                      4                4
# 12                         1                      4                4
# 13                         1                      4                4
# 14                         1                      5                5
#
#             Positive highlights of generation process  \
# 1                  Very good performance in general.
# 2   Very well structured and explained. Abbrevatio...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7    ordena muy bien los resultados de la ecografía.
# 8                                                 NaN
# 9                                                 NaN
# 10  datos muy completos, estrcutura fiel al docume...
# 11                                                NaN
# 12                                                NaN
# 13              Muy bien especificado Chief complaint
# 14                                                NaN
#
#             Negative highlights of generation process  \
# 1   Lack of some information e.g., desfibrillator ...
# 2   The text has been oversummarized, leaving out ...
# 4   Too much information omitted and the text is o...
# 5                                                 NaN
# 6   falta información sobre tipo de prótesis, ause...
# 7   Faltan los datos hemodinámicos cardiacos y pul...
# 8   falta información: mencionar estudio de trombo...
# 9                                                 NaN
# 10  La parte correspondiente a la  enfermedad actu...
# 11  Se pierde mucha información sobre la explicaci...
# 12  Se debería mencionar el motivo de admisión: an...
# 13  Se podría separar la enfermedad actual de los ...
# 14  la razón de admisión suele ser algo más genera...
#
#     Other comments on Generated/Original data sources
# 1                                                 NaN
# 2                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN

# %%
auto_path = "output/samples/en/phase_2/phase_2.csv"
df_auto = pd.read_csv(auto_path).rename(columns={"filename": "filenameid"})
df_auto["filenameid"] = df_auto["filenameid"].astype(str)
df_auto = df_auto.drop(columns=["cluster"])
df_auto = df_auto[df_auto["filenameid"].isin(eval_filenames)]
df_auto.dtypes
# Out:
# filenameid     object
# precision     float64
# recall        float64
# f1            float64
# tp              int64
# fp              int64
# fn              int64
# dtype: object

# %%
df_total = df_model_eval.merge(df_human_eval, on="filenameid", suffixes=("_model", "_human"))
df_total = df_total.merge(df_auto, on="filenameid")
df_total_num = df_total.select_dtypes(int)
df_total_num
# Out:
#    Content Relevance_model  Information Completeness_model  \
# 0                        5                               5
# 1                        5                               5
# 2                        5                               5
# 3                        5                               5
# 4                        5                               5
# 5                        5                               5
# 6                        5                               5
# 7                        5                               5
# 8                        5                               5
#
#    Clarity and Structure_model  Content Accuracy_model  Hallucinations_model  \
# 0                            5                       5                     1
# 1                            5                       5                     1
# 2                            5                       5                     1
# 3                            5                       5                     1
# 4                            5                       5                     1
# 5                            5                       5                     1
# 6                            5                       5                     1
# 7                            5                       5                     1
# 8                            5                       5                     1
#
#    Impact of Hallucinations_model  Relevance to Practice_model  \
# 0                               1                            5
# 1                               1                            5
# 2                               1                            5
# 3                               1                            5
# 4                               1                            5
# 5                               1                            5
# 6                               1                            5
# 7                               1                            5
# 8                               1                            5
#
#    Overall Quality_model  Content Relevance_human  \
# 0                      4                        4
# 1                      4                        4
# 2                      4                        5
# 3                      4                        5
# 4                      4                        5
# 5                      4                        5
# 6                      4                        5
# 7                      4                        5
# 8                      4                        4
#
#    Information Completeness_human  Clarity and Structure_human  \
# 0                               4                            4
# 1                               3                            4
# 2                               5                            3
# 3                               5                            4
# 4                               5                            4
# 5                               5                            4
# 6                               4                            5
# 7                               5                            5
# 8                               3                            4
#
#    Content Accuracy_human  Hallucinations_human  \
# 0                       5                     1
# 1                       4                     1
# 2                       5                     1
# 3                       4                     1
# 4                       4                     1
# 5                       5                     1
# 6                       5                     1
# 7                       5                     1
# 8                       3                     1
#
#    Impact of Hallucinations_human  Relevance to Practice_human  \
# 0                               1                            5
# 1                               1                            4
# 2                               1                            3
# 3                               1                            4
# 4                               1                            4
# 5                               1                            5
# 6                               1                            5
# 7                               1                            5
# 8                               1                            3
#
#    Overall Quality_human  tp  fp  fn
# 0                      4  13   2   9
# 1                      4   4   8   5
# 2                      4  34   3  29
# 3                      4  24   5  11
# 4                      4  24   3   1
# 5                      5   6   4   3
# 6                      5  12   4   1
# 7                      5   3   2   0
# 8                      3  29   8  13

# %%
nan_cols = ["Hallucinations_model", "Impact of Hallucinations_model", "Hallucinations_human", "Impact of Hallucinations_human"]

human_cols = [col for col in df_total_num.columns if "human" in col and col not in nan_cols]
model_cols = [col for col in df_total_num.columns if "model" in col and col not in nan_cols]

model_human_corr = df_total_num.corr().loc[model_cols, human_cols]

sns.heatmap(model_human_corr, annot=True, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Model vs Human Evaluation Correlation");
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_FOLDER, "model_human_corr.png"), dpi=300)

# %%
pearsonr(df_total["Overall Quality_model"], df_total["Overall Quality_human"])
# Out:
# /scratch/tmp/ipykernel_3270393/1850672205.py:1: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   pearsonr(df_total["Overall Quality_model"], df_total["Overall Quality_human"])
# PearsonRResult(statistic=nan, pvalue=nan)

# %% [markdown]
# # Auto Evaluation

# %%
import numpy as np

auto_cols = df_auto.select_dtypes(np.number).columns

model_auto_corr = df_total.select_dtypes(np.number).corr().loc[model_cols, auto_cols]

sns.heatmap(model_auto_corr, annot=True, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Model vs Auto Evaluation Correlation");

plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_FOLDER, "model_auto_corr.png"), dpi=300)

# %%
pearsonr(df_total["f1"], df_total["Overall Quality_model"])
# Out:
# /scratch/tmp/ipykernel_3270393/1266032647.py:1: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   pearsonr(df_total["f1"], df_total["Overall Quality_model"])
# PearsonRResult(statistic=nan, pvalue=nan)

# %%
# Now human versus auto

human_auto_corr = df_total.select_dtypes(np.number).corr().loc[human_cols, auto_cols]

sns.heatmap(human_auto_corr, annot=True, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Human vs Auto Evaluation Correlation");

plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_FOLDER, "human_auto_corr.png"), dpi=300)

# %%
from scipy.stats import pearsonr
def compute_score(df_auto, df_human, col_auto, col_human):
    return pearsonr(df_auto[col_auto], df_human[col_human])

compute_score(df_auto, df_total, col_auto="f1", col_human="Overall Quality_human")
# Out:
# PearsonRResult(statistic=0.32947607723927924, pvalue=0.3865879552281516)

# %%
compute_score(df_auto, df_total, col_auto="f1", col_human="Overall Quality_model")
# Out:
# /scratch/tmp/ipykernel_3270393/3762423379.py:3: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return pearsonr(df_auto[col_auto], df_human[col_human])
# PearsonRResult(statistic=nan, pvalue=nan)

# %%
compute_score(df_total, df_total, col_auto="Overall Quality_human", col_human="Overall Quality_model")
# Out:
# /scratch/tmp/ipykernel_3270393/3762423379.py:3: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return pearsonr(df_auto[col_auto], df_human[col_human])
# PearsonRResult(statistic=nan, pvalue=nan)

# %% [markdown]
# # Metrics

# %%
pearson_auto_human = compute_score(df_auto, df_total, col_auto="f1", col_human="Overall Quality_human")
pearson_auto_model = compute_score(df_auto, df_total, col_auto="f1", col_human="Overall Quality_model")
pearson_human_model = compute_score(df_total, df_total, col_auto="Overall Quality_human", col_human="Overall Quality_model")

df_metrics_pearson = pd.DataFrame([pearson_auto_human, pearson_auto_model, pearson_human_model], columns=["pearson", "p-value"], index=["auto_human", "auto_model", "human_model"])
df_metrics_pearson.to_csv(os.path.join(OUTPUT_FOLDER, "pearson_metrics.csv"))
# Out:
# /scratch/tmp/ipykernel_3270393/3762423379.py:3: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return pearsonr(df_auto[col_auto], df_human[col_human])

# %%
df_metrics_pearson
# Out:
#               pearson   p-value
# auto_human   0.329476  0.386588
# auto_model        NaN       NaN
# human_model       NaN       NaN
